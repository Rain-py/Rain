# %%
import numpy as np
import sys

sys.path.append('../../../src')
from Rain.Rain import Rain
sys.path.pop()
# Out:
# '../../../src'

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
np.random.seed(63)
X = np.random.randn(250, 2)

# %%
config = {
  "mode": {
      "type": "local",
      "params": {
        "num_of_workers": 3,
      }
  },
  "temp_data_path": "../../../",
  "partitions": 3,
  "iterations": 20,
  "chunk_size": 1024*1024,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "KMeans",
      "params": {
        "K": 3,
      }
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-10 19:02:42,203 [INFO] [Rain] Rain is initialized
# 2023-07-10 19:02:42,214 [INFO] [Provisioner] Creating coordinator
# 2023-07-10 19:02:42,225 [INFO] [Coordinator] Coordinator is initialized
# 2023-07-10 19:02:42,232 [INFO] [LocalProvisioner] Provisioner is initialized

# %%
model = rain.train(X, None)
# Out:
# 2023-07-10 19:02:42,288 [INFO] [Provisioner] provisioner is serving
# 2023-07-10 19:02:42,290 [INFO] [Provisioner] Starting coordinator
# 2023-07-10 19:02:42,292 [INFO] [Coordinator] coordinator is serving
# 2023-07-10 19:02:42,305 [INFO] [LocalProvisioner] Creating 3 workers
# 2023-07-10 19:02:42,318 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-10 19:02:42,329 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-10 19:02:42,346 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-10 19:02:42,351 [INFO] [Provisioner] [Created workers]: IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-10 19:02:42,356 [INFO] [DividerProxy] Training Started
# 2023-07-10 19:02:42,362 [INFO] [MachineLearning] Starting iteration 1/20
# 2023-07-10 19:02:42,369 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:42,372 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:42,376 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:42,452 [INFO] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-10 19:02:42,453 [INFO] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-10 19:02:42,457 [INFO] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-10 19:02:42,458 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-10 19:02:42,460 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-10 19:02:42,463 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-10 19:02:42,581 [INFO] [MachineLearning] Iteration 1/20 complete.
# 2023-07-10 19:02:42,583 [INFO] [MachineLearning] Starting iteration 2/20
# 2023-07-10 19:02:42,592 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:42,593 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:42,594 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:42,615 [INFO] [DividerAmbassador] divider begins executing iteration2 for worker1
# 2023-07-10 19:02:42,617 [INFO] [DividerAmbassador] divider begins executing iteration2 for worker2
# 2023-07-10 19:02:42,620 [INFO] [DividerAmbassador] divider begins executing iteration2 for worker3
# 2023-07-10 19:02:42,622 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 2
# 2023-07-10 19:02:42,624 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 2
# 2023-07-10 19:02:42,630 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 2
# 2023-07-10 19:02:42,708 [INFO] [MachineLearning] Iteration 2/20 complete.
# 2023-07-10 19:02:42,710 [INFO] [MachineLearning] Starting iteration 3/20
# 2023-07-10 19:02:42,724 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:42,726 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:42,726 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-10 19:02:42,750 [INFO] [DividerAmbassador] divider begins executing iteration3 for worker1
# 2023-07-10 19:02:42,751 [INFO] [DividerAmbassador] divider begins executing iteration3 for worker2
# 2023-07-10 19:02:42,753 [INFO] [DividerAmbassador] divider begins executing iteration3 for worker3
# 2023-07-10 19:02:42,759 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 3
# 2023-07-10 19:02:42,761 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 3
# 2023-07-10 19:02:42,763 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 3
# 2023-07-10 19:02:42,842 [INFO] [MachineLearning] Iteration 3/20 complete.
# 2023-07-10 19:02:42,844 [INFO] [MachineLearning] Starting iteration 4/20
# 2023-07-10 19:02:42,853 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:42,855 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:42,856 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:42,876 [INFO] [DividerAmbassador] divider begins executing iteration4 for worker3
# 2023-07-10 19:02:42,876 [INFO] [DividerAmbassador] divider begins executing iteration4 for worker1
# 2023-07-10 19:02:42,878 [INFO] [DividerAmbassador] divider begins executing iteration4 for worker2
# 2023-07-10 19:02:42,881 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 4
# 2023-07-10 19:02:42,884 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 4
# 2023-07-10 19:02:42,887 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 4
# 2023-07-10 19:02:42,961 [INFO] [MachineLearning] Iteration 4/20 complete.
# 2023-07-10 19:02:42,962 [INFO] [MachineLearning] Starting iteration 5/20
# 2023-07-10 19:02:42,970 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:42,972 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:42,972 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:42,990 [INFO] [DividerAmbassador] divider begins executing iteration5 for worker2
# 2023-07-10 19:02:42,992 [INFO] [DividerAmbassador] divider begins executing iteration5 for worker1
# 2023-07-10 19:02:42,995 [INFO] [DividerAmbassador] divider begins executing iteration5 for worker3
# 2023-07-10 19:02:42,997 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 5
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-10 19:02:42,999 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 5
# 2023-07-10 19:02:43,001 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 5
# 2023-07-10 19:02:43,081 [INFO] [MachineLearning] Iteration 5/20 complete.
# 2023-07-10 19:02:43,083 [INFO] [MachineLearning] Starting iteration 6/20
# 2023-07-10 19:02:43,089 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:43,090 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:43,091 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:43,112 [INFO] [DividerAmbassador] divider begins executing iteration6 for worker1
# 2023-07-10 19:02:43,113 [INFO] [DividerAmbassador] divider begins executing iteration6 for worker2
# 2023-07-10 19:02:43,113 [INFO] [DividerAmbassador] divider begins executing iteration6 for worker3
# 2023-07-10 19:02:43,118 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 6
# 2023-07-10 19:02:43,120 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 6
# 2023-07-10 19:02:43,122 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 6
# 2023-07-10 19:02:43,190 [INFO] [MachineLearning] Iteration 6/20 complete.
# 2023-07-10 19:02:43,191 [INFO] [MachineLearning] Starting iteration 7/20
# 2023-07-10 19:02:43,197 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:43,198 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:43,199 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:43,219 [INFO] [DividerAmbassador] divider begins executing iteration7 for worker2
# 2023-07-10 19:02:43,220 [INFO] [DividerAmbassador] divider begins executing iteration7 for worker3
# 2023-07-10 19:02:43,224 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 7
# 2023-07-10 19:02:43,225 [INFO] [DividerAmbassador] divider begins executing iteration7 for worker1
# 2023-07-10 19:02:43,227 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 7
# 2023-07-10 19:02:43,232 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 7
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-10 19:02:43,297 [INFO] [MachineLearning] Iteration 7/20 complete.
# 2023-07-10 19:02:43,299 [INFO] [MachineLearning] Starting iteration 8/20
# 2023-07-10 19:02:43,305 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:43,306 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:43,307 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:43,331 [INFO] [DividerAmbassador] divider begins executing iteration8 for worker2
# 2023-07-10 19:02:43,332 [INFO] [DividerAmbassador] divider begins executing iteration8 for worker3
# 2023-07-10 19:02:43,334 [INFO] [DividerAmbassador] divider begins executing iteration8 for worker1
# 2023-07-10 19:02:43,337 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 8
# 2023-07-10 19:02:43,340 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 8
# 2023-07-10 19:02:43,342 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 8
# 2023-07-10 19:02:43,409 [INFO] [MachineLearning] Iteration 8/20 complete.
# 2023-07-10 19:02:43,410 [INFO] [MachineLearning] Starting iteration 9/20
# 2023-07-10 19:02:43,416 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:43,418 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:43,421 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:43,442 [INFO] [DividerAmbassador] divider begins executing iteration9 for worker3
# 2023-07-10 19:02:43,444 [INFO] [DividerAmbassador] divider begins executing iteration9 for worker1
# 2023-07-10 19:02:43,446 [INFO] [DividerAmbassador] divider begins executing iteration9 for worker2
# 2023-07-10 19:02:43,449 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 9
# 2023-07-10 19:02:43,452 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 9
# 2023-07-10 19:02:43,455 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 9
# sending data to dividersending data to divider
#
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-10 19:02:43,525 [INFO] [MachineLearning] Iteration 9/20 complete.
# 2023-07-10 19:02:43,527 [INFO] [MachineLearning] Starting iteration 10/20
# 2023-07-10 19:02:43,537 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:43,538 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:43,540 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:43,559 [INFO] [DividerAmbassador] divider begins executing iteration10 for worker1
# 2023-07-10 19:02:43,560 [INFO] [DividerAmbassador] divider begins executing iteration10 for worker2
# 2023-07-10 19:02:43,563 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 10
# 2023-07-10 19:02:43,566 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 10
# 2023-07-10 19:02:43,597 [INFO] [DividerAmbassador] divider begins executing iteration10 for worker3
# 2023-07-10 19:02:43,606 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 10
# 2023-07-10 19:02:43,660 [INFO] [MachineLearning] Iteration 10/20 complete.
# 2023-07-10 19:02:43,661 [INFO] [MachineLearning] Starting iteration 11/20
# 2023-07-10 19:02:43,667 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:43,668 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:43,668 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# sending data to dividersending data to divider
#
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-10 19:02:43,695 [INFO] [DividerAmbassador] divider begins executing iteration11 for worker1
# 2023-07-10 19:02:43,695 [INFO] [DividerAmbassador] divider begins executing iteration11 for worker2
# 2023-07-10 19:02:43,696 [INFO] [DividerAmbassador] divider begins executing iteration11 for worker3
# 2023-07-10 19:02:43,700 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 11
# 2023-07-10 19:02:43,702 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 11
# 2023-07-10 19:02:43,703 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 11
# 2023-07-10 19:02:43,774 [INFO] [MachineLearning] Iteration 11/20 complete.
# 2023-07-10 19:02:43,775 [INFO] [MachineLearning] Starting iteration 12/20
# 2023-07-10 19:02:43,784 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:43,786 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:43,786 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:43,809 [INFO] [DividerAmbassador] divider begins executing iteration12 for worker3
# 2023-07-10 19:02:43,810 [INFO] [DividerAmbassador] divider begins executing iteration12 for worker1
# 2023-07-10 19:02:43,811 [INFO] [DividerAmbassador] divider begins executing iteration12 for worker2
# 2023-07-10 19:02:43,815 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 12
# 2023-07-10 19:02:43,816 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 12
# 2023-07-10 19:02:43,820 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 12
# 2023-07-10 19:02:43,881 [INFO] [MachineLearning] Iteration 12/20 complete.
# 2023-07-10 19:02:43,882 [INFO] [MachineLearning] Starting iteration 13/20
# 2023-07-10 19:02:43,890 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:43,892 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:43,893 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:43,911 [INFO] [DividerAmbassador] divider begins executing iteration13 for worker1
# 2023-07-10 19:02:43,912 [INFO] [DividerAmbassador] divider begins executing iteration13 for worker2
# 2023-07-10 19:02:43,916 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 13
# 2023-07-10 19:02:43,917 [INFO] [DividerAmbassador] divider begins executing iteration13 for worker3
# 2023-07-10 19:02:43,919 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 13
# 2023-07-10 19:02:43,921 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 13
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-10 19:02:43,985 [INFO] [MachineLearning] Iteration 13/20 complete.
# 2023-07-10 19:02:43,986 [INFO] [MachineLearning] Starting iteration 14/20
# 2023-07-10 19:02:43,992 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:43,993 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:43,993 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:44,015 [INFO] [DividerAmbassador] divider begins executing iteration14 for worker2
# 2023-07-10 19:02:44,016 [INFO] [DividerAmbassador] divider begins executing iteration14 for worker3
# 2023-07-10 19:02:44,019 [INFO] [DividerAmbassador] divider begins executing iteration14 for worker1
# 2023-07-10 19:02:44,024 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 14
# 2023-07-10 19:02:44,025 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 14
# 2023-07-10 19:02:44,026 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 14
# 2023-07-10 19:02:44,092 [INFO] [MachineLearning] Iteration 14/20 complete.
# 2023-07-10 19:02:44,094 [INFO] [MachineLearning] Starting iteration 15/20
# 2023-07-10 19:02:44,100 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:44,101 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:44,102 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:44,131 [INFO] [DividerAmbassador] divider begins executing iteration15 for worker2
# 2023-07-10 19:02:44,131 [INFO] [DividerAmbassador] divider begins executing iteration15 for worker1
# 2023-07-10 19:02:44,134 [INFO] [DividerAmbassador] divider begins executing iteration15 for worker3
# 2023-07-10 19:02:44,138 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 15
# 2023-07-10 19:02:44,139 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 15
# 2023-07-10 19:02:44,142 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 15
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-10 19:02:44,216 [INFO] [MachineLearning] Iteration 15/20 complete.
# 2023-07-10 19:02:44,219 [INFO] [MachineLearning] Starting iteration 16/20
# 2023-07-10 19:02:44,225 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:44,226 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:44,228 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:44,252 [INFO] [DividerAmbassador] divider begins executing iteration16 for worker3
# 2023-07-10 19:02:44,255 [INFO] [DividerAmbassador] divider begins executing iteration16 for worker2
# 2023-07-10 19:02:44,256 [INFO] [DividerAmbassador] divider begins executing iteration16 for worker1
# 2023-07-10 19:02:44,259 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 16
# 2023-07-10 19:02:44,262 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 16
# 2023-07-10 19:02:44,264 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 16
# 2023-07-10 19:02:44,330 [INFO] [MachineLearning] Iteration 16/20 complete.
# 2023-07-10 19:02:44,332 [INFO] [MachineLearning] Starting iteration 17/20
# 2023-07-10 19:02:44,338 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:44,340 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:44,341 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:44,356 [INFO] [DividerAmbassador] divider begins executing iteration17 for worker1
# 2023-07-10 19:02:44,357 [INFO] [DividerAmbassador] divider begins executing iteration17 for worker2
# 2023-07-10 19:02:44,363 [INFO] [DividerAmbassador] divider begins executing iteration17 for worker3
# 2023-07-10 19:02:44,364 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 17
# 2023-07-10 19:02:44,367 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 17
# 2023-07-10 19:02:44,369 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 17
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-10 19:02:44,439 [INFO] [MachineLearning] Iteration 17/20 complete.
# 2023-07-10 19:02:44,463 [INFO] [MachineLearning] Starting iteration 18/20
# 2023-07-10 19:02:44,473 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:44,475 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:44,475 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:44,500 [INFO] [DividerAmbassador] divider begins executing iteration18 for worker1
# 2023-07-10 19:02:44,501 [INFO] [DividerAmbassador] divider begins executing iteration18 for worker2
# 2023-07-10 19:02:44,503 [INFO] [DividerAmbassador] divider begins executing iteration18 for worker3
# 2023-07-10 19:02:44,508 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 18
# 2023-07-10 19:02:44,509 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 18
# 2023-07-10 19:02:44,511 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 18
# 2023-07-10 19:02:44,573 [INFO] [MachineLearning] Iteration 18/20 complete.
# 2023-07-10 19:02:44,576 [INFO] [MachineLearning] Starting iteration 19/20
# 2023-07-10 19:02:44,582 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:44,583 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:44,583 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# sending data to dividersending data to divider
#
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-10 19:02:44,603 [INFO] [DividerAmbassador] divider begins executing iteration19 for worker3
# 2023-07-10 19:02:44,603 [INFO] [DividerAmbassador] divider begins executing iteration19 for worker1
# 2023-07-10 19:02:44,604 [INFO] [DividerAmbassador] divider begins executing iteration19 for worker2
# 2023-07-10 19:02:44,607 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 19
# 2023-07-10 19:02:44,609 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 19
# 2023-07-10 19:02:44,613 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 19
# 2023-07-10 19:02:44,675 [INFO] [MachineLearning] Iteration 19/20 complete.
# 2023-07-10 19:02:44,677 [INFO] [MachineLearning] Starting iteration 20/20
# 2023-07-10 19:02:44,685 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50151
# 2023-07-10 19:02:44,686 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50152
# 2023-07-10 19:02:44,686 [INFO] [DividerAmbassador] Executing one iteration of federated learning on 127.0.0.1:50153
# 2023-07-10 19:02:44,706 [INFO] [DividerAmbassador] divider begins executing iteration20 for worker2
# 2023-07-10 19:02:44,707 [INFO] [DividerAmbassador] divider begins executing iteration20 for worker1
# 2023-07-10 19:02:44,710 [INFO] [DividerAmbassador] divider begins executing iteration20 for worker3
# 2023-07-10 19:02:44,713 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 20
# 2023-07-10 19:02:44,714 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 20
# 2023-07-10 19:02:44,715 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 20
# 2023-07-10 19:02:44,779 [INFO] [MachineLearning] Iteration 20/20 complete.
# 2023-07-10 19:02:44,781 [INFO] [Divider] Divider stopped serving
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider

# %%
labels = model.get_labels(X)

# %%
# Plot the data (X) along with the labels as colors
import matplotlib.pyplot as plt

color_map = {0: 'red', 1: 'blue', 2: 'green'}

for label in set(labels):
    label_data = [d for d, l in zip(X, labels) if l == label]
    plt.scatter(*zip(*label_data), color=color_map[label], label=f"Cluster {label + 1}")


# Set labels for axes
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Rain Distributed K-means Clustering')

# Create the legend
plt.legend()
# Show the plot
plt.show()

# %%
del rain
# Out:
# 2023-07-10 19:02:45,107 [INFO] [Worker_50151] Worker stopped serving on port: 50151
# 2023-07-10 19:02:45,111 [INFO] [Worker_50152] Worker stopped serving on port: 50152
# 2023-07-10 19:02:45,113 [INFO] [Worker_50153] Worker stopped serving on port: 50153
# 2023-07-10 19:02:45,117 [INFO] [LocalProvisioner] Workers are deleted
# 2023-07-10 19:02:45,118 [INFO] [Provisioner] provisioner stopped serving
