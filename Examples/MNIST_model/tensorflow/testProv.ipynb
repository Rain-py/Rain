# %%
import sys
import numpy as np

from Rain.Rain import Rain

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import tensorflow as tf
# Out:
# 2023-07-05 06:54:29.327771: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-05 06:54:30.190104: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
config = {
  "mode": {
      "type": "cloud",
      "params": {
          "num_of_workers": 1,
          "subscription_id": 'a7ef3688-af58-4835-953c-e51f219fbd0f', # Mostafa's ID
          # "subscription_id": '82305756-d4a0-442d-8e73-625e1ced2113', # Nada's ID
          "location": 'eastus'
      }
      
    },
  "temp_data_path": "../../../",
  "partitions": 1,
  "iterations": 2,
  "learning_type": "DL",
  "DL": {
    "lib": {
      "type": "tensorflow",
      "params": {
        "loss": tf.keras.losses.CategoricalCrossentropy(),
        "optimizer": tf.keras.optimizers.Adam(learning_rate=0.001),

      }
    },
    "lr": 0.001,
    "epochs": 1,
    "batch_size": 128,
  }
}

# %%
sys.path.append("../../../")
from Rain.Provisioner.CloudProvisioner import CloudProvisioner
sys.path.pop()
# Out:
# '../../../'

# %%
subscription_id = config["mode"]["params"]["subscription_id"]
location = config["mode"]["params"]["location"]

prov = CloudProvisioner(subscription_id=subscription_id,
                                    location=location)
# Out:
# 2023-07-05 06:54:31,060 [DEBUG] [TemporaryFilesManager] Created temporary directory /tmp/RainData/prov/
# 2023-07-05 06:54:31,061 [DEBUG] [CloudProvisioner] Provisioner is initialized

# %%
prov.create_workers(1)
# Out:
# 2023-07-05 06:54:31,066 [DEBUG] [CloudProvisioner] Setup the networking for the workers
# 2023-07-05 06:54:37,939 [DEBUG] [CloudProvisioner] Created resource group: Rain-resourcegroup
# 2023-07-05 06:54:59,501 [DEBUG] [CloudProvisioner] Created virtual network: Rain-vnet
# 2023-07-05 06:55:04,491 [DEBUG] [CloudProvisioner] Created network security group: Rain-nic-nsg
# 2023-07-05 06:55:04,495 [DEBUG] [CloudProvisioner] Network setup completed
# 2023-07-05 06:55:04,498 [DEBUG] [CloudProvisioner] Creating 1 worker
# 2023-07-05 06:55:04,516 [DEBUG] [CloudProvisioner] Created SSH key pair at /tmp/RainData/prov//private_key.pem and /tmp/RainData/prov//public_key.pem
# 2023-07-05 06:55:04,517 [DEBUG] [CloudProvisioner] Creating worker Rain-vm1
# 2023-07-05 06:55:08,667 [DEBUG] [CloudProvisioner] Created public IP address: Rain-nic-Rain-vm1-ip
# 2023-07-05 06:55:13,017 [DEBUG] [CloudProvisioner] Created network interface: Rain-nic-Rain-vm1
# 2023-07-05 06:56:01,554 [DEBUG] [CloudProvisioner] Created virtual machine: Rain-vm1
# 2023-07-05 06:56:01,557 [INFO] [CloudProvisioner] Created worker Rain-vm1
# 2023-07-05 06:56:02,267 [INFO] [CloudProvisioner] Worker 1 is up on 52.149.158.176:50151

# %%
prov.delete_workers()
# Out:
# 2023-07-05 07:10:32,964 [DEBUG] [CloudProvisioner] Deleting virtual machine: Rain-vm1
# 2023-07-05 07:11:04,512 [DEBUG] [CloudProvisioner] Deleting network interface: Rain-nic-Rain-vm1
# 2023-07-05 07:11:06,557 [DEBUG] [CloudProvisioner] Deleting public IP address: Rain-nic-Rain-vm1-ip
# 2023-07-05 07:11:07,377 [DEBUG] [CloudProvisioner] Deleting network security group: Rain-nic-nsg
# 2023-07-05 07:11:08,179 [DEBUG] [CloudProvisioner] Deleting virtual network: Rain-vnet
# 2023-07-05 07:11:08,974 [DEBUG] [CloudProvisioner] Deleting resource group: Rain-resourcegroup
# 2023-07-05 07:13:14,684 [DEBUG] [CloudProvisioner] Networking cleanup completed
# 2023-07-05 07:13:14,688 [DEBUG] [CloudProvisioner] Workers are deleted
