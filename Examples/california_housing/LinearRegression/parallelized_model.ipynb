# %%
import numpy as np
import sys
from sklearn.preprocessing import StandardScaler

sys.path.append('../../../src')
from Rain.Rain import Rain
sys.path.pop()
# Out:
# '../../../src'

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/california_housing/train_data.npy"), np.load("../../../data/california_housing/train_labels.npy")

def get_test_data():
    return np.load("../../../data/california_housing/test_data.npy"), np.load("../../../data/california_housing/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
config = {
  "mode": {
      "type": "local",
      "params": {
        "num_of_workers": 3,
      }
  },
  "temp_data_path": "../../../",
  "partitions": 3,
  "iterations": 50,
  "chunk_size": 1024*1024,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "LinearRegression",
      "params": {
        "lr": 0.1
      }
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-08 11:59:48,184 [DEBUG] [Rain] Rain is initialized
# 2023-07-08 11:59:48,190 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-08 11:59:48,196 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-08 11:59:48,202 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-08 11:59:48,206 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-08 11:59:48,215 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-08 11:59:48,224 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-08 11:59:48,233 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-08 11:59:48,258 [INFO] [Provisioner] provisioner is serving
# 2023-07-08 11:59:48,260 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-08 11:59:48,262 [INFO] [Coordinator] coordinator is serving
# 2023-07-08 11:59:48,264 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-08 11:59:48,270 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-08 11:59:48,272 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-08 11:59:48,278 [DEBUG] [Coordinator] coordinator is sending the number of workers to provisioner
# 2023-07-08 11:59:48,281 [DEBUG] [Provisioner] Provision requested the coordinator to get the number of workers
# 2023-07-08 11:59:48,283 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-08 11:59:48,290 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50151/
# 2023-07-08 11:59:48,296 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-08 11:59:48,302 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50152/
# 2023-07-08 11:59:48,311 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-08 11:59:48,318 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50153/
# 2023-07-08 11:59:48,328 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-08 11:59:48,329 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-08 11:59:48,331 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-08 11:59:48,333 [DEBUG] [DividerProxy] Training Started
# 2023-07-08 11:59:48,340 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-08 11:59:48,344 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-08 11:59:48,346 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-08 11:59:48,348 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-08 11:59:48,350 [DEBUG] [MachineLearning] Starting iteration 1/50
# 2023-07-08 11:59:48,361 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 11:59:48,362 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 11:59:48,362 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 11:59:48,418 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-08 11:59:48,419 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-08 11:59:48,450 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 1 after sending y_train
# 2023-07-08 11:59:48,451 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 2 after sending y_train
# 2023-07-08 11:59:48,454 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 11:59:48,456 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 11:59:48,473 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 11:59:48,475 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 11:59:48,476 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-08 11:59:48,477 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-08 11:59:48,480 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-08 11:59:48,482 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-08 11:59:48,585 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 11:59:48,587 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 11:59:48,594 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-08 11:59:48,595 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-08 11:59:48,622 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-08 11:59:48,625 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-08 11:59:48,645 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-08 11:59:48,678 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 3 after sending y_train
# 2023-07-08 11:59:48,680 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 11:59:48,693 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 11:59:48,695 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-08 11:59:48,697 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# sending data to divider
# sending data to divider
# 2023-07-08 11:59:48,846 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 11:59:48,847 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-08 11:59:48,860 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-08 11:59:48,878 [DEBUG] [MachineLearning] Iteration 1/50 complete.
# 2023-07-08 11:59:48,880 [DEBUG] [MachineLearning] Starting iteration 2/50
# 2023-07-08 11:59:48,889 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 11:59:48,891 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 11:59:48,892 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 2 to worker 1
# 2023-07-08 11:59:48,894 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 2 to worker 2
# 2023-07-08 11:59:48,894 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 11:59:48,895 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 11:59:48,896 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 11:59:48,897 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 2 to worker 3
# 2023-07-08 11:59:48,901 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 11:59:48,919 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 11:59:48,921 [DEBUG] [DividerAmbassador] divider begins executing iteration2 for worker2
# 2023-07-08 11:59:48,922 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 2
# 2023-07-08 11:59:48,934 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 11:59:48,936 [DEBUG] [DividerAmbassador] divider begins executing iteration2 for worker1
# 2023-07-08 11:59:48,942 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 11:59:48,943 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 2
# 2023-07-08 11:59:48,944 [DEBUG] [DividerAmbassador] divider begins executing iteration2 for worker3
# 2023-07-08 11:59:48,947 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 2
# 2023-07-08 11:59:48,999 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 11:59:49,012 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_2_trained.pkl from worker2
# sending data to divider
# sending data to divider
# 2023-07-08 11:59:49,061 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 11:59:49,063 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_2_trained.pkl from worker3
# 2023-07-08 11:59:49,068 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_2_trained.pkl from worker2 successfully
# 2023-07-08 11:59:49,076 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 11:59:49,078 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_2_trained.pkl from worker1
# 2023-07-08 11:59:49,094 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_2_trained.pkl from worker3 successfully
# 2023-07-08 11:59:49,102 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1
[DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 11:59:50,724 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 11:59:50,726 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 11:59:50,729 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 11 to worker 1
# 2023-07-08 11:59:50,732 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 11 to worker 2
# 2023-07-08 11:59:50,736 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 11 to worker 3
# 2023-07-08 11:59:50,741 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 11:59:50,746 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 11:59:50,749 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 11:59:50,771 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 11:59:50,773 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-08 11:59:50,780 [DEBUG] [DividerAmbassador] divider begins executing iteration11 for worker1
# 2023-07-08 11:59:50,782 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 11:59:50,783 [DEBUG] [DividerAmbassador] divider begins executing iteration11 for worker2
# 2023-07-08 11:59:50,788 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 11
# 2023-07-08 11:59:50,792 [DEBUG] [DividerAmbassador] divider begins executing iteration11 for worker3
# 2023-07-08 11:59:50,797 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 11
# 2023-07-08 11:59:50,802 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 11
# 2023-07-08 11:59:50,845 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 11:59:50,881 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_11_trained.pkl from worker1
# 2023-07-08 11:59:50,918 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 11:59:50,933 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_11_trained.pkl from worker1 successfully
# 2023-07-08 11:59:50,937 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_11_trained.pkl from worker2
# 2023-07-08 11:59:50,960 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 11:59:50,979 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_11_trained.pkl from worker3
# 2023-07-08 11:59:50,998 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_11_trained.pkl from worker2 successfully
# 2023-07-08 11:59:51,014 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_11_trained.pkl from worker3 successfully
# 2023-07-08 11:59:51,032 [DEBUG] [MachineLearning] Iteration 11/50 complete.
# 2023-07-08 11:59:51,033 [DEBUG] [MachineLearning] Starting iteration 12/50
# 2023-07-08 11:59:51,042 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 11:59:51,043 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 11:59:51,044 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-08 11:59:51,047 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 12 to worker 1
# 2023-07-08 11:59:51,050 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 12 to worker 2
# 2023-07-08 11:59:51,053 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 12 to worker 3
# 2023-07-08 11:59:51,059 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 11:59:51,062 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 11:59:51,065 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 11:59:51,085 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 11:59:51,090 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 11:59:51,094 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 11:59:51,094 [DEBUG] [DividerAmbassador] divider begins executing iteration12 for worker1
# 2023-07-08 11:59:51,097 [DEBUG] [DividerAmbassador] divider begins executing iteration12 for worker2
# 2023-07-08 11:59:51,101 [DEBUG] [DividerAmbassador] divider begins executing iteration12 for worker3
# 2023-07-08 11:59:51,107 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 12
# 2023-07-08 11:59:51,112 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 12
# 2023-07-08 11:59:51,116 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 12
# 2023-07-08 11:59:51,164 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 11:59:51,173 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_12_trained.pkl from worker1
# 2023-07-08 11:59:51,196 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 11:59:51,206 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 11:59:51,212 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_12_trained.pkl from worker2
# 2023-07-08 11:59:51,217 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_12_trained.pkl from worker3
# 2023-07-08 11:59:51,237 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_12_trained.pkl from worker1 successfully
# 2023-07-08 11:59:51,248 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_12_trained.pkl from worker2 successfully
# 2023-07-08 11:59:51,253 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_12_trained.pkl from worker3 successfully
# 2023-07-08 11:59:51,271 [DEBUG] [MachineLearning] Iteration 12/50 complete.
# 2023-07-08 11:59:51,273 [DEBUG] [MachineLearning] Starting iteration 13/50
# 2023-07-08 11:59:51,280 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 11:59:51,281 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 11:59:51,282 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 11:59:51,284 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 13 to worker 1
# 2023-07-08 11:59:51,288 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 13 to worker 2
# 2023-07-08 11:59:51,293 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 13 to worker 3
# 2023-07-08 11:59:51,295 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 11:59:51,298 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 11:59:51,302 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 11:59:51,321 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 11:59:51,324 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 11:59:51,326 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 11:59:51,326 [DEBUG] [DividerAmbassador] divider begins executing iteration13 for worker1
# 2023-07-08 11:59:51,333 [DEBUG] [DividerAmbassador] divider begins executing iteration13 for worker2
# 2023-07-08 11:59:51,337 [DEBUG] [DividerAmbassador] divider begins executing iteration13 for worker3
# 2023-07-08 11:59:51,341 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 13
# 2023-07-08 11:59:51,344 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 13
# 2023-07-08 11:59:51,350 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 13
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-08 11:59:51,400 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 11:59:51,415 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 11:59:51,415 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 11:59:51,437 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_13_trained.pkl from worker1
# 2023-07-08 11:59:51,446 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_13_trained.pkl from worker3
# 2023-07-08 11:59:51,463 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_13_trained.pkl from worker2
# 2023-07-08 11:59:51,498 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_13_trained.pkl from worker1 successfully
# 2023-07-08 11:59:51,507 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_13_trained.pkl from worker3 successfully
# 2023-07-08 11:59:51,511 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_13_trained.pkl from worker2 successfully
# 2023-07-08 11:59:51,530 [DEBUG] [MachineLearning] Iteration 13/50 complete.
# 2023-07-08 11:59:51,531 [DEBUG] [MachineLearning] Starting iteration 14/50
# 2023-07-08 11:59:51,538 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 11:59:51,540 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 11:59:51,541 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 11:59:51,544 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 14 to worker 1
# 2023-07-08 11:59:51,547 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 14 to worker 2
# 2023-07-08 11:59:51,551 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 14 to worker 3
# 2023-07-08 11:59:51,556 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 11:59:51,560 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 11:59:51,563 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 11:59:51,584 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 11:59:51,585 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 11:59:51,593 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 11:59:51,594 [DEBUG] [DividerAmbassador] divider begins executing iteration14 for worker1
# 2023-07-08 11:59:51,597 [DEBUG] [DividerAmbassador] divider begins executing iteration14 for worker2
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-08 11:59:51,600 [DEBUG] [DividerAmbassador] divider begins executing iteration14 for worker3
# 2023-07-08 11:59:51,606 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 14
# 2023-07-08 11:59:51,611 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 14
# 2023-07-08 11:59:51,615 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 14
# 2023-07-08 11:59:51,673 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 11:59:51,675 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 11:59:51,678 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_14_trained.pkl from worker3
# 2023-07-08 11:59:51,681 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_14_trained.pkl from worker1
# 2023-07-08 11:59:51,712 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 11:59:51,746 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_14_trained.pkl from worker3 successfully
# 2023-07-08 11:59:51,748 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_14_trained.pkl from worker2
# 2023-07-08 11:59:51,771 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_14_trained.pkl from worker1 successfully
# 2023-07-08 11:59:51,780 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_14_trained.pkl from worker2 successfully
# 2023-07-08 11:59:51,798 [DEBUG] [MachineLearning] Iteration 14/50 complete.
# 2023-07-08 11:59:51,799 [DEBUG] [MachineLearning] Starting iteration 15/50
# 2023-07-08 11:59:51,807 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 11:59:51,809 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 11:59:51,809 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 11:59:51,812 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 15 to worker 1
# ...
# 2023-07-08 12:00:00,100 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 46 to worker 2
# 2023-07-08 12:00:00,104 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 46 to worker 3
# 2023-07-08 12:00:00,106 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 12:00:00,111 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 12:00:00,114 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 12:00:00,130 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 12:00:00,133 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 12:00:00,137 [DEBUG] [DividerAmbassador] divider begins executing iteration46 for worker1
# 2023-07-08 12:00:00,141 [DEBUG] [DividerAmbassador] divider begins executing iteration46 for worker2
# 2023-07-08 12:00:00,141 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-08 12:00:00,147 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 46
# 2023-07-08 12:00:00,150 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 46
# 2023-07-08 12:00:00,153 [DEBUG] [DividerAmbassador] divider begins executing iteration46 for worker3
# 2023-07-08 12:00:00,161 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 46
# 2023-07-08 12:00:00,209 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 12:00:00,232 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 12:00:00,232 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_46_trained.pkl from worker2
# 2023-07-08 12:00:00,248 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_46_trained.pkl from worker1
# 2023-07-08 12:00:00,273 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_46_trained.pkl from worker2 successfully
# 2023-07-08 12:00:00,273 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_46_trained.pkl from worker1 successfully
# 2023-07-08 12:00:00,302 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 12:00:00,309 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_46_trained.pkl from worker3
# 2023-07-08 12:00:00,345 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_46_trained.pkl from worker3 successfully
# 2023-07-08 12:00:00,365 [DEBUG] [MachineLearning] Iteration 46/50 complete.
# 2023-07-08 12:00:00,366 [DEBUG] [MachineLearning] Starting iteration 47/50
# 2023-07-08 12:00:00,374 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 12:00:00,376 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 12:00:00,377 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 12:00:00,379 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 47 to worker 1
# 2023-07-08 12:00:00,382 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 47 to worker 2
# 2023-07-08 12:00:00,387 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 47 to worker 3
# 2023-07-08 12:00:00,390 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 12:00:00,394 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 12:00:00,398 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-08 12:00:00,418 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 12:00:00,420 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 12:00:00,425 [DEBUG] [DividerAmbassador] divider begins executing iteration47 for worker1
# 2023-07-08 12:00:00,428 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 12:00:00,430 [DEBUG] [DividerAmbassador] divider begins executing iteration47 for worker2
# 2023-07-08 12:00:00,434 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 47
# 2023-07-08 12:00:00,437 [DEBUG] [DividerAmbassador] divider begins executing iteration47 for worker3
# 2023-07-08 12:00:00,442 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 47
# 2023-07-08 12:00:00,451 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 47
# 2023-07-08 12:00:00,490 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 12:00:00,506 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_47_trained.pkl from worker1
# 2023-07-08 12:00:00,526 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 12:00:00,530 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 12:00:00,549 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_47_trained.pkl from worker2
# 2023-07-08 12:00:00,554 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_47_trained.pkl from worker3
# 2023-07-08 12:00:00,586 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_47_trained.pkl from worker1 successfully
# 2023-07-08 12:00:00,599 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_47_trained.pkl from worker3 successfully
# 2023-07-08 12:00:00,604 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_47_trained.pkl from worker2 successfully
# 2023-07-08 12:00:00,622 [DEBUG] [MachineLearning] Iteration 47/50 complete.
# 2023-07-08 12:00:00,625 [DEBUG] [MachineLearning] Starting iteration 48/50
# 2023-07-08 12:00:00,631 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 12:00:00,631 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 12:00:00,632 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 12:00:00,636 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 48 to worker 1
# 2023-07-08 12:00:00,639 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 48 to worker 2
# 2023-07-08 12:00:00,644 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 48 to worker 3
# 2023-07-08 12:00:00,647 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 12:00:00,649 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 12:00:00,653 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 12:00:00,679 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 12:00:00,680 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 12:00:00,686 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 12:00:00,687 [DEBUG] [DividerAmbassador] divider begins executing iteration48 for worker2
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-08 12:00:00,690 [DEBUG] [DividerAmbassador] divider begins executing iteration48 for worker1
# 2023-07-08 12:00:00,694 [DEBUG] [DividerAmbassador] divider begins executing iteration48 for worker3
# 2023-07-08 12:00:00,699 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 48
# 2023-07-08 12:00:00,703 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 48
# 2023-07-08 12:00:00,706 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 48
# 2023-07-08 12:00:00,754 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 12:00:00,768 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_48_trained.pkl from worker1
# 2023-07-08 12:00:00,773 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 12:00:00,784 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 12:00:00,813 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_48_trained.pkl from worker2
# 2023-07-08 12:00:00,818 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_48_trained.pkl from worker3
# 2023-07-08 12:00:00,837 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_48_trained.pkl from worker1 successfully
# 2023-07-08 12:00:00,850 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_48_trained.pkl from worker2 successfully
# 2023-07-08 12:00:00,852 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_48_trained.pkl from worker3 successfully
# 2023-07-08 12:00:00,870 [DEBUG] [MachineLearning] Iteration 48/50 complete.
# 2023-07-08 12:00:00,871 [DEBUG] [MachineLearning] Starting iteration 49/50
# 2023-07-08 12:00:00,880 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 12:00:00,881 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 12:00:00,882 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 12:00:00,885 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 49 to worker 1
# 2023-07-08 12:00:00,888 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 49 to worker 2
# 2023-07-08 12:00:00,894 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 49 to worker 3
# 2023-07-08 12:00:00,897 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 12:00:00,900 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 12:00:00,903 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 12:00:00,921 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 12:00:00,925 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 12:00:00,926 [DEBUG] [DividerAmbassador] divider begins executing iteration49 for worker1
# 2023-07-08 12:00:00,930 [DEBUG] [DividerAmbassador] divider begins executing iteration49 for worker2
# 2023-07-08 12:00:00,930 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 12:00:00,938 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 49
# 2023-07-08 12:00:00,941 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 49
# 2023-07-08 12:00:00,944 [DEBUG] [DividerAmbassador] divider begins executing iteration49 for worker3
# 2023-07-08 12:00:00,950 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 49
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-08 12:00:01,016 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 12:00:01,021 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 12:00:01,028 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_49_trained.pkl from worker1
# 2023-07-08 12:00:01,043 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 12:00:01,044 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_49_trained.pkl from worker2
# 2023-07-08 12:00:01,078 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_49_trained.pkl from worker3
# 2023-07-08 12:00:01,094 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_49_trained.pkl from worker1 successfully
# 2023-07-08 12:00:01,101 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_49_trained.pkl from worker2 successfully
# 2023-07-08 12:00:01,104 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_49_trained.pkl from worker3 successfully
# 2023-07-08 12:00:01,121 [DEBUG] [MachineLearning] Iteration 49/50 complete.
# 2023-07-08 12:00:01,124 [DEBUG] [MachineLearning] Starting iteration 50/50
# 2023-07-08 12:00:01,130 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 12:00:01,131 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 12:00:01,132 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 12:00:01,134 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 50 to worker 1
# 2023-07-08 12:00:01,138 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 50 to worker 2
# 2023-07-08 12:00:01,143 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration 50 to worker 3
# 2023-07-08 12:00:01,146 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 12:00:01,150 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 12:00:01,152 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-08 12:00:01,197 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 12:00:01,203 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 12:00:01,206 [DEBUG] [DividerAmbassador] divider begins executing iteration50 for worker1
# 2023-07-08 12:00:01,214 [DEBUG] [DividerAmbassador] divider begins executing iteration50 for worker2
# 2023-07-08 12:00:01,220 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 12:00:01,223 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 50
# 2023-07-08 12:00:01,227 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 50
# 2023-07-08 12:00:01,229 [DEBUG] [DividerAmbassador] divider begins executing iteration50 for worker3
# 2023-07-08 12:00:01,237 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 50
# 2023-07-08 12:00:01,262 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 12:00:01,289 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_50_trained.pkl from worker1
# 2023-07-08 12:00:01,309 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 12:00:01,310 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 12:00:01,329 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_50_trained.pkl from worker2
# 2023-07-08 12:00:01,340 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_50_trained.pkl from worker3
# 2023-07-08 12:00:01,369 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_50_trained.pkl from worker1 successfully
# 2023-07-08 12:00:01,396 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_50_trained.pkl from worker2 successfully
# 2023-07-08 12:00:01,399 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_50_trained.pkl from worker3 successfully
# 2023-07-08 12:00:01,417 [DEBUG] [MachineLearning] Iteration 50/50 complete.
# 2023-07-08 12:00:01,419 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-08 12:00:01,422 [DEBUG] [Divider] Divider stopped serving
# sending data to divider
# sending data to divider
# sending data to divider

# %%
from sklearn import metrics
y_pred = model.predict(X_test)
print(f'R2 score: {metrics.r2_score(y_test, y_pred)}')
print(f'MSE: {metrics.mean_squared_error(y_test, y_pred)}')
# Out:
# R2 score: 0.5676395329197652
# MSE: 0.5835565411682005
