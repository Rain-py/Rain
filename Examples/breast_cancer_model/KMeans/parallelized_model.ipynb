# %%
import numpy as np
import sys
sys.path.append("../../../")
from Rain.Rain import Rain
from Rain.Divider.MachineLearning.KMeans import KMeans
sys.path.pop()
# Out:
# '../../../'

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
np.random.seed(63)
X = np.random.randn(200, 2)  # Assuming 100 data points with 2 features
# y = None

# %%
config = {
  "mode": {
      "type": "local",
      "params": {}
  },
  "partitions": 3,
  "num_of_workers": 3,
  "iterations": 10,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "KMeans",
      "params": {
        "K": 2,
      }
    }    
  }
}

# %%
# model = KMeans(config=config)
rain = Rain(config)
# Out:
# 2023-07-04 08:11:01,181 [DEBUG] [Rain] Rain is initialized
# 2023-07-04 08:11:01,183 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-04 08:11:01,184 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../../Rain_data/coord/
# 2023-07-04 08:11:01,186 [DEBUG] [Coordinator Ambassador] Coordinator Ambassador is initialized
# 2023-07-04 08:11:01,528 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-04 08:11:01,529 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../../Rain_data/coord/
# 2023-07-04 08:11:01,530 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-04 08:11:01,531 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../../Rain_data/divider/
# 2023-07-04 08:11:01,532 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../../Rain_data/divider/
# 2023-07-04 08:11:01,534 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../../Rain_data/divider/

# %%
model = rain.train(X, None)
# Out:
# 2023-07-04 08:11:01,540 [DEBUG] [Rain] Creating workers
# 2023-07-04 08:11:01,553 [INFO] [Provisioner] provisioner is serving
# 2023-07-04 08:11:01,554 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-04 08:11:01,556 [INFO] [Coordinator] coordinator is serving
# 2023-07-04 08:11:01,556 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-04 08:11:01,563 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-04 08:11:01,564 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-04 08:11:01,565 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-04 08:11:01,566 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../../Rain_data/worker/
# 2023-07-04 08:11:01,569 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-04 08:11:01,570 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../../Rain_data/worker/
# 2023-07-04 08:11:01,572 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-04 08:11:01,573 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../../Rain_data/worker/
# 2023-07-04 08:11:01,576 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-04 08:11:01,577 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 08:11:01,579 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-04 08:11:01,580 [DEBUG] [DividerProxy] Sending data to workers
# 2023-07-04 08:11:01,580 [DEBUG] [DividerProxy] Training Started
# 2023-07-04 08:11:01,582 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-04 08:11:01,584 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-04 08:11:01,585 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 08:11:01,587 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-04 08:11:01,588 [DEBUG] [MachineLearning] Starting iteration 1/10
# 2023-07-04 08:11:01,595 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 08:11:01,595 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 08:11:01,595 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 08:11:01,605 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 08:11:01,606 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 08:11:01,606 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 08:11:01,610 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 08:11:01,611 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 08:11:01,612 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 08:11:01,612 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/2.pkl to worker2
# 2023-07-04 08:11:01,613 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/1.pkl to worker1
# 2023-07-04 08:11:01,613 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/3.pkl to worker3
# 2023-07-04 08:11:01,616 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 08:11:01,617 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 08:11:01,618 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-04 08:11:01,619 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 08:11:01,619 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-04 08:11:01,620 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-04 08:11:01,621 [INFO] [Worker_50152] Executing command: python3 ../../../Rain/Worker/Algo.py 2 ../../../../Rain_data/worker/ 1
# 2023-07-04 08:11:01,622 [INFO] [Worker_50151] Executing command: python3 ../../../Rain/Worker/Algo.py 1 ../../../../Rain_data/worker/ 1
# 2023-07-04 08:11:01,622 [INFO] [Worker_50153] Executing command: python3 ../../../Rain/Worker/Algo.py 3 ../../../../Rain_data/worker/ 1
# [{'config': {'mode': {'type': 'local', 'params': {}}, 'partitions': 3, 'num_of_workers': 3, 'iterations': 10, 'learning_type': 'ML', 'ML': {'algorithm': {'type': 'KMeans', 'params': {'K': 2}}}}, 'model': <class 'Rain.Divider.MachineLearning.KMeans.Model'>}]
# sending data to coordinator
# sending data to coordinator
# sending data to coordinator
# 2023-07-04 08:11:03,334 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 1
# 2023-07-04 08:11:03,335 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/1_1_trained.pkl from worker1
# 2023-07-04 08:11:03,337 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-04 08:11:03,338 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 2
# 2023-07-04 08:11:03,338 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 3
# 2023-07-04 08:11:03,340 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/2_1_trained.pkl from worker2
# 2023-07-04 08:11:03,340 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/3_1_trained.pkl from worker3
# 2023-07-04 08:11:03,343 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-04 08:11:03,344 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-04 08:11:03,346 [DEBUG] [MachineLearning] Iteration 1/10 complete.
# 2023-07-04 08:11:03,346 [DEBUG] [MachineLearning] Starting iteration 2/10
# 2023-07-04 08:11:03,348 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04
[INFO] [Worker_50152] Executing command: python3 ../../../Rain/Worker/Algo.py 2 ../../../../Rain_data/worker/ 5
# 2023-07-04 08:11:08,214 [INFO] [Worker_50153] Executing command: python3 ../../../Rain/Worker/Algo.py 3 ../../../../Rain_data/worker/ 5
# [{'config': {'mode': {'type': 'local', 'params': {}}, 'partitions': 3, 'num_of_workers': 3, 'iterations': 10, 'learning_type': 'ML', 'ML': {'algorithm': {'type': 'KMeans', 'params': {'K': 2}}}}, 'model': <class 'Rain.Divider.MachineLearning.KMeans.Model'>}]
# sending data to coordinator
# sending data to coordinator
# sending data to coordinator
# 2023-07-04 08:11:09,665 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 2
# 2023-07-04 08:11:09,666 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/2_5_trained.pkl from worker2
# 2023-07-04 08:11:09,668 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/2_5_trained.pkl from worker2 successfully
# 2023-07-04 08:11:09,696 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 1
# 2023-07-04 08:11:09,698 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/1_5_trained.pkl from worker1
# 2023-07-04 08:11:09,700 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/1_5_trained.pkl from worker1 successfully
# 2023-07-04 08:11:09,705 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 3
# 2023-07-04 08:11:09,705 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/3_5_trained.pkl from worker3
# 2023-07-04 08:11:09,708 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/3_5_trained.pkl from worker3 successfully
# 2023-07-04 08:11:09,709 [DEBUG] [MachineLearning] Iteration 5/10 complete.
# 2023-07-04 08:11:09,710 [DEBUG] [MachineLearning] Starting iteration 6/10
# 2023-07-04 08:11:09,711 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 08:11:09,711 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 08:11:09,712 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 08:11:09,712 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/1.pkl to worker1
# 2023-07-04 08:11:09,713 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/2.pkl to worker2
# 2023-07-04 08:11:09,714 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/3.pkl to worker3
# 2023-07-04 08:11:09,717 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 08:11:09,717 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 08:11:09,718 [DEBUG] [DividerAmbassador] divider begins executing iteration6 for worker2
# 2023-07-04 08:11:09,718 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 08:11:09,719 [DEBUG] [DividerAmbassador] divider begins executing iteration6 for worker1
# 2023-07-04 08:11:09,720 [INFO] [Worker_50152] Executing command: python3 ../../../Rain/Worker/Algo.py 2 ../../../../Rain_data/worker/ 6
# 2023-07-04 08:11:09,720 [DEBUG] [DividerAmbassador] divider begins executing iteration6 for worker3
# 2023-07-04 08:11:09,721 [INFO] [Worker_50151] Executing command: python3 ../../../Rain/Worker/Algo.py 1 ../../../../Rain_data/worker/ 6
# 2023-07-04 08:11:09,722 [INFO] [Worker_50153] Executing command: python3 ../../../Rain/Worker/Algo.py 3 ../../../../Rain_data/worker/ 6
# [{'config': {'mode': {'type': 'local', 'params': {}}, 'partitions': 3, 'num_of_workers': 3, 'iterations': 10, 'learning_type': 'ML', 'ML': {'algorithm': {'type': 'KMeans', 'params': {'K': 2}}}}, 'model': <class 'Rain.Divider.MachineLearning.KMeans.Model'>}]
# sending data to coordinator
# sending data to coordinator
# sending data to coordinator
# 2023-07-04 08:11:11,371 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 2
# 2023-07-04 08:11:11,372 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/2_6_trained.pkl from worker2
# 2023-07-04 08:11:11,374 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/2_6_trained.pkl from worker2 successfully
# 2023-07-04 08:11:11,408 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 3
# 2023-07-04 08:11:11,409 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/3_6_trained.pkl from worker3
# 2023-07-04 08:11:11,411 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/3_6_trained.pkl from worker3 successfully
# 2023-07-04 08:11:11,444 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 1
# 2023-07-04 08:11:11,445 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/1_6_trained.pkl from worker1
# 2023-07-04 08:11:11,447 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/1_6_trained.pkl from worker1 successfully
# 2023-07-04 08:11:11,449 [DEBUG] [MachineLearning] Iteration 6/10 complete.
# 2023-07-04 08:11:11,449 [DEBUG] [MachineLearning] Starting iteration 7/10
# 2023-07-04 08:11:11,451 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 08:11:11,451 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 08:11:11,451 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 08:11:11,453 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/1.pkl to worker1
# 2023-07-04 08:11:11,453 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/2.pkl to worker2
# 2023-07-04 08:11:11,454 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/3.pkl to worker3
# 2023-07-04 08:11:11,457 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 08:11:11,458 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 08:11:11,458 [DEBUG] [DividerAmbassador] divider begins executing iteration7 for worker1
# 2023-07-04 08:11:11,459 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 08:11:11,459 [DEBUG] [DividerAmbassador] divider begins executing iteration7 for worker2
# 2023-07-04 08:11:11,460 [INFO] [Worker_50151] Executing command: python3 ../../../Rain/Worker/Algo.py 1 ../../../../Rain_data/worker/ 7
# 2023-07-04 08:11:11,461 [DEBUG] [DividerAmbassador] divider begins executing iteration7 for worker3
# 2023-07-04 08:11:11,462 [INFO] [Worker_50152] Executing command: python3 ../../../Rain/Worker/Algo.py 2 ../../../../Rain_data/worker/ 7
# 2023-07-04 08:11:11,462 [INFO] [Worker_50153] Executing command: python3 ../../../Rain/Worker/Algo.py 3 ../../../../Rain_data/worker/ 7
# [{'config': {'mode': {'type': 'local', 'params': {}}, 'partitions': 3, 'num_of_workers': 3, 'iterations': 10, 'learning_type': 'ML', 'ML': {'algorithm': {'type': 'KMeans', 'params': {'K': 2}}}}, 'model': <class 'Rain.Divider.MachineLearning.KMeans.Model'>}]
# sending data to coordinator
# sending data to coordinator
# sending data to coordinator
# 2023-07-04 08:11:12,963 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 3
# 2023-07-04 08:11:12,964 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/3_7_trained.pkl from worker3
# 2023-07-04 08:11:12,966 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/3_7_trained.pkl from worker3 successfully
# 2023-07-04 08:11:13,111 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 1
# 2023-07-04 08:11:13,112 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/1_7_trained.pkl from worker1
# 2023-07-04 08:11:13,116 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/1_7_trained.pkl from worker1 successfully
# 2023-07-04 08:11:13,134 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 2
# 2023-07-04 08:11:13,135 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/2_7_trained.pkl from worker2
# 2023-07-04 08:11:13,137 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/2_7_trained.pkl from worker2 successfully
# 2023-07-04 08:11:13,138 [DEBUG] [MachineLearning] Iteration 7/10 complete.
# 2023-07-04 08:11:13,139 [DEBUG] [MachineLearning] Starting iteration 8/10
# 2023-07-04 08:11:13,141 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 08:11:13,142 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 08:11:13,142 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 08:11:13,143 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/1.pkl to worker1
# 2023-07-04 08:11:13,144 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/2.pkl to worker2
# 2023-07-04 08:11:13,145 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/3.pkl to worker3
# 2023-07-04 08:11:13,148 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 08:11:13,148 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 08:11:13,149 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 08:11:13,149 [DEBUG] [DividerAmbassador] divider begins executing iteration8 for worker1
# 2023-07-04 08:11:13,150 [DEBUG] [DividerAmbassador] divider begins executing iteration8 for worker2
# 2023-07-04 08:11:13,150 [DEBUG] [DividerAmbassador] divider begins executing iteration8 for worker3
# 2023-07-04 08:11:13,152 [INFO] [Worker_50151] Executing command: python3 ../../../Rain/Worker/Algo.py 1 ../../../../Rain_data/worker/ 8
# 2023-07-04 08:11:13,153 [INFO] [Worker_50152] Executing command: python3 ../../../Rain/Worker/Algo.py 2 ../../../../Rain_data/worker/ 8
# 2023-07-04 08:11:13,153 [INFO] [Worker_50153] Executing command: python3 ../../../Rain/Worker/Algo.py 3 ../../../../Rain_data/worker/ 8
# [{'config': {'mode': {'type': 'local', 'params': {}}, 'partitions': 3, 'num_of_workers': 3, 'iterations': 10, 'learning_type': 'ML', 'ML': {'algorithm': {'type': 'KMeans', 'params': {'K': 2}}}}, 'model': <class 'Rain.Divider.MachineLearning.KMeans.Model'>}]
# sending data to coordinator
# sending data to coordinator
# sending data to coordinator
# 2023-07-04 08:11:14,703 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 1
# 2023-07-04 08:11:14,703 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 2
# 2023-07-04 08:11:14,703 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 3
# 2023-07-04 08:11:14,705 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/1_8_trained.pkl from worker1
# 2023-07-04 08:11:14,706 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/2_8_trained.pkl from worker2
# 2023-07-04 08:11:14,707 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/3_8_trained.pkl from worker3
# 2023-07-04 08:11:14,709 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/1_8_trained.pkl from worker1 successfully
# 2023-07-04 08:11:14,711 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/2_8_trained.pkl from worker2 successfully
# 2023-07-04 08:11:14,711 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/3_8_trained.pkl from worker3 successfully
# 2023-07-04 08:11:14,712 [DEBUG] [MachineLearning] Iteration 8/10 complete.
# 2023-07-04 08:11:14,713 [DEBUG] [MachineLearning] Starting iteration 9/10
# 2023-07-04 08:11:14,715 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 08:11:14,715 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 08:11:14,716 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 08:11:14,717 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/1.pkl to worker1
# 2023-07-04 08:11:14,718 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/2.pkl to worker2
# 2023-07-04 08:11:14,719 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/3.pkl to worker3
# 2023-07-04 08:11:14,721 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 08:11:14,722 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 08:11:14,724 [DEBUG] [DividerAmbassador] divider begins executing iteration9 for worker1
# 2023-07-04 08:11:14,725 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 08:11:14,726 [DEBUG] [DividerAmbassador] divider begins executing iteration9 for worker2
# 2023-07-04 08:11:14,727 [INFO] [Worker_50151] Executing command: python3 ../../../Rain/Worker/Algo.py 1 ../../../../Rain_data/worker/ 9
# 2023-07-04 08:11:14,727 [DEBUG] [DividerAmbassador] divider begins executing iteration9 for worker3
# 2023-07-04 08:11:14,728 [INFO] [Worker_50152] Executing command: python3 ../../../Rain/Worker/Algo.py 2 ../../../../Rain_data/worker/ 9
# 2023-07-04 08:11:14,730 [INFO] [Worker_50153] Executing command: python3 ../../../Rain/Worker/Algo.py 3 ../../../../Rain_data/worker/ 9
# [{'config': {'mode': {'type': 'local', 'params': {}}, 'partitions': 3, 'num_of_workers': 3, 'iterations': 10, 'learning_type': 'ML', 'ML': {'algorithm': {'type': 'KMeans', 'params': {'K': 2}}}}, 'model': <class 'Rain.Divider.MachineLearning.KMeans.Model'>}]
# sending data to coordinator
# sending data to coordinator
# sending data to coordinator
# 2023-07-04 08:11:16,550 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 1
# 2023-07-04 08:11:16,551 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/1_9_trained.pkl from worker1
# 2023-07-04 08:11:16,554 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/1_9_trained.pkl from worker1 successfully
# 2023-07-04 08:11:16,563 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 2
# 2023-07-04 08:11:16,565 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/2_9_trained.pkl from worker2
# 2023-07-04 08:11:16,568 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/2_9_trained.pkl from worker2 successfully
# 2023-07-04 08:11:16,577 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 3
# 2023-07-04 08:11:16,578 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/3_9_trained.pkl from worker3
# 2023-07-04 08:11:16,580 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/3_9_trained.pkl from worker3 successfully
# 2023-07-04 08:11:16,583 [DEBUG] [MachineLearning] Iteration 9/10 complete.
# 2023-07-04 08:11:16,584 [DEBUG] [MachineLearning] Starting iteration 10/10
# 2023-07-04 08:11:16,585 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 08:11:16,585 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 08:11:16,586 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 08:11:16,588 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/1.pkl to worker1
# 2023-07-04 08:11:16,589 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/2.pkl to worker2
# 2023-07-04 08:11:16,591 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/divider/3.pkl to worker3
# 2023-07-04 08:11:16,594 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 08:11:16,595 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 08:11:16,596 [DEBUG] [DividerAmbassador] divider begins executing iteration10 for worker1
# 2023-07-04 08:11:16,597 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 08:11:16,598 [DEBUG] [DividerAmbassador] divider begins executing iteration10 for worker2
# 2023-07-04 08:11:16,600 [INFO] [Worker_50151] Executing command: python3 ../../../Rain/Worker/Algo.py 1 ../../../../Rain_data/worker/ 10
# 2023-07-04 08:11:16,601 [DEBUG] [DividerAmbassador] divider begins executing iteration10 for worker3
# 2023-07-04 08:11:16,602 [INFO] [Worker_50152] Executing command: python3 ../../../Rain/Worker/Algo.py 2 ../../../../Rain_data/worker/ 10
# 2023-07-04 08:11:16,603 [INFO] [Worker_50153] Executing command: python3 ../../../Rain/Worker/Algo.py 3 ../../../../Rain_data/worker/ 10
# [{'config': {'mode': {'type': 'local', 'params': {}}, 'partitions': 3, 'num_of_workers': 3, 'iterations': 10, 'learning_type': 'ML', 'ML': {'algorithm': {'type': 'KMeans', 'params': {'K': 2}}}}, 'model': <class 'Rain.Divider.MachineLearning.KMeans.Model'>}]
# sending data to coordinator
# sending data to coordinator
# sending data to coordinator
# 2023-07-04 08:11:18,072 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 1
# 2023-07-04 08:11:18,073 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/1_10_trained.pkl from worker1
# 2023-07-04 08:11:18,075 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/1_10_trained.pkl from worker1 successfully
# 2023-07-04 08:11:18,079 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 3
# 2023-07-04 08:11:18,080 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/3_10_trained.pkl from worker3
# 2023-07-04 08:11:18,082 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/3_10_trained.pkl from worker3 successfully
# 2023-07-04 08:11:18,093 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 2
# 2023-07-04 08:11:18,094 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/divider/2_10_trained.pkl from worker2
# 2023-07-04 08:11:18,096 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/divider/2_10_trained.pkl from worker2 successfully
# 2023-07-04 08:11:18,098 [DEBUG] [MachineLearning] Iteration 10/10 complete.
# 2023-07-04 08:11:18,099 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 08:11:18,099 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 08:11:18,100 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 08:11:18,101 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 08:11:18,101 [INFO] [Provisioner] provisioner stopped serving

# %%
def calculate_distances(X, cluster_centers):
    n_clusters = cluster_centers.shape[0]
    n_samples = X.shape[0]
    distances = np.zeros((n_samples, n_clusters))

    for cluster in range(n_clusters):
        distances[:, cluster] = np.linalg.norm(X - cluster_centers[cluster], axis=1)

    return distances

distances = calculate_distances(X, model.cluster_centers)
labels = np.argmin(distances, axis=1)

# %%
# Plot the data (X) along with the labels as colors
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

for i in range(len(X)):
    if labels[i] == 0:
        plt.scatter(X[i, 0], X[i, 1], c='red')
    elif labels[i] == 1:
        plt.scatter(X[i, 0], X[i, 1], c='blue')
    elif labels[i] == 2:
        plt.scatter(X[i, 0], X[i, 1], c='green')
    elif labels[i] == 3:
        plt.scatter(X[i, 0], X[i, 1], c='yellow')

# Set labels for axes
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()
# Out:
# 2023-07-04 08:12:04,774 [DEBUG] [Coordinator] coordinator is sending workers info to divider
