# %%
import numpy as np
import sys
sys.path.append("../../../src/")
from Rain.Rain import Rain
sys.path.pop()
# Out:
# 2023-07-05 22:38:22.735439: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-05 22:38:23.429835: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# '../../../src/'

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
np.random.seed(63)
X = np.random.randn(200, 2)

# %%
config = {
  "mode": {
      "type": "local",
      "params": {
        "num_of_workers": 3,
      }
  },
  "temp_data_path": "../../../../Rain_data",
  "partitions": 3,
  "iterations": 20,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "KMeans",
      "params": {
        "K": 2,
      }
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-05 22:38:24,310 [ERROR] [Rain] Error in the config: Error in partitions: argument of type 'int' is not iterable
# 2023-07-05 22:38:24,311 [DEBUG] [Rain] Rain is initialized
# 2023-07-05 22:38:24,312 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-05 22:38:24,313 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../../../Rain_data/RainData/coord/
# 2023-07-05 22:38:24,314 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-05 22:38:24,315 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-05 22:38:24,316 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../../../Rain_data/RainData/divider/
# 2023-07-05 22:38:24,318 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../../../Rain_data/RainData/divider/
# 2023-07-05 22:38:24,319 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../../../Rain_data/RainData/divider/

# %%
model = rain.train(X, None)
# Out:
# 2023-07-05 22:38:24,330 [INFO] [Provisioner] provisioner is serving
# 2023-07-05 22:38:24,331 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-05 22:38:24,332 [INFO] [Coordinator] coordinator is serving
# 2023-07-05 22:38:24,334 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-05 22:38:24,339 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-05 22:38:24,340 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-05 22:38:24,341 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-05 22:38:24,342 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../../../Rain_data/RainData/worker_50151/
# 2023-07-05 22:38:24,344 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-05 22:38:24,346 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../../../Rain_data/RainData/worker_50152/
# 2023-07-05 22:38:24,347 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-05 22:38:24,348 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../../../Rain_data/RainData/worker_50153/
# 2023-07-05 22:38:24,350 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-05 22:38:24,352 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-05 22:38:24,353 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-05 22:38:24,354 [DEBUG] [DividerProxy] Training Started
# 2023-07-05 22:38:24,357 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-05 22:38:24,358 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-05 22:38:24,360 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-05 22:38:24,361 [DEBUG] [MachineLearning] Starting iteration 1/20
# 2023-07-05 22:38:24,362 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,363 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,363 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,368 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-05 22:38:24,369 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-05 22:38:24,370 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-05 22:38:24,373 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-05 22:38:24,374 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-05 22:38:24,374 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-05 22:38:24,375 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,376 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,376 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,379 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,380 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,381 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,381 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-05 22:38:24,382 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-05 22:38:24,382 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-05 22:38:24,384 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-05 22:38:24,385 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-05 22:38:24,386 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-05 22:38:24,390 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,390 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,390 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,392 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_1_trained.pkl from worker2
# 2023-07-05 22:38:24,393 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_1_trained.pkl from worker3
# 2023-07-05 22:38:24,394 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_1_trained.pkl from worker1
# 2023-07-05 22:38:24,397 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,397 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,398 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,401 [DEBUG] [MachineLearning] Iteration 1/20 complete.
# 2023-07-05 22:38:24,402 [DEBUG] [MachineLearning] Starting iteration 2/20
# 2023-07-05 22:38:24,403 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,404 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,404 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,405 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration2 to worker1
# 2023-07-05 22:38:24,406 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration2 to worker2
# 2023-07-05 22:38:24,406 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration2 to worker3
# 2023-07-05 22:38:24,407 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,407 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,408 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,411 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,412 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,413 [DEBUG] [DividerAmbassador] divider begins executing iteration2 for worker1
# 2023-07-05 22:38:24,413 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,415 [DEBUG] [DividerAmbassador] divider begins executing iteration2 for worker2
# 2023-07-05 22:38:24,416 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 2
# 2023-07-05 22:38:24,416 [DEBUG] [DividerAmbassador] divider begins executing iteration2 for worker3
# 2023-07-05 22:38:24,418 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 2
# 2023-07-05 22:38:24,419 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 2
# 2023-07-05 22:38:24,421 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,423 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,423 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,424 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_2_trained.pkl from worker1
# 2023-07-05 22:38:24,425 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_2_trained.pkl from worker3
# 2023-07-05 22:38:24,425 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_2_trained.pkl from worker2
# 2023-07-05 22:38:24,429 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_2_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,430 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_2_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,430 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_2_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,432 [DEBUG] [MachineLearning] Iteration 2/20 complete.
# 2023-07-05 22:38:24,433 [DEBUG] [MachineLearning] Starting iteration 3/20
# 2023-07-05 22:38:24,435 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,436 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,436 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,437 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration3 to worker1
# 2023-07-05 22:38:24,438 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration3 to worker2
# 2023-07-05 22:38:24,438 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration3 to worker3
# 2023-07-05 22:38:24,439 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,439 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,440 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,444 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,445 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,446 [DEBUG] [DividerAmbassador] divider begins executing iteration3 for worker1
# 2023-07-05 22:38:24,446 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,447 [DEBUG] [DividerAmbassador] divider begins executing iteration3 for worker2
# 2023-07-05 22:38:24,448 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 3
# 2023-07-05 22:38:24,448 [DEBUG] [DividerAmbassador] divider begins executing iteration3 for worker3
# 2023-07-05 22:38:24,449 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 3
# 2023-07-05 22:38:24,450 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 3
# 2023-07-05 22:38:24,453 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,454 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_3_trained.pkl from worker1
# 2023-07-05 22:38:24,455 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,456 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,457 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_3_trained.pkl from worker2
# 2023-07-05 22:38:24,459 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_3_trained.pkl from worker3
# 2023-07-05 22:38:24,460 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_3_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,463 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_3_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,464 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_3_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,465 [DEBUG] [MachineLearning] Iteration 3/20 complete.
# 2023-07-05 22:38:24,466 [DEBUG] [MachineLearning] Starting iteration 4/20
# 2023-07-05 22:38:24,468 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,469 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,469 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,470 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration4 to worker1
# 2023-07-05 22:38:24,471 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration4 to worker2
# 2023-07-05 22:38:24,471 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration4 to worker3
# 2023-07-05 22:38:24,472 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,472 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,473 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,481 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,483 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,486 [DEBUG] [DividerAmbassador] divider begins executing iteration4 for worker2
# 2023-07-05 22:38:24,487 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,488 [DEBUG] [DividerAmbassador] divider begins executing iteration4 for worker1
# 2023-07-05 22:38:24,490 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 4
# 2023-07-05 22:38:24,490 [DEBUG] [DividerAmbassador] divider begins executing iteration4 for worker3
# 2023-07-05 22:38:24,491 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 4
# 2023-07-05 22:38:24,495 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 4
# 2023-07-05 22:38:24,496 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,497 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_4_trained.pkl from worker2
# 2023-07-05 22:38:24,500 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,504 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,504 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_4_trained.pkl from worker1
# 2023-07-05 22:38:24,505 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_4_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,506 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_4_trained.pkl from worker3
# 2023-07-05 22:38:24,510 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_4_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,513 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_4_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,515 [DEBUG] [MachineLearning] Iteration 4/20 complete.
# 2023-07-05 22:38:24,516 [DEBUG] [MachineLearning] Starting iteration 5/20
# 2023-07-05 22:38:24,519 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,520 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,521 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,521 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration5 to worker1
# 2023-07-05 22:38:24,522 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration5 to worker2
# 2023-07-05 22:38:24,523 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration5 to worker3
# 2023-07-05 22:38:24,524 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,525 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,527 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,530 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,531 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,532 [DEBUG] [DividerAmbassador] divider begins executing iteration5 for worker1
# 2023-07-05 22:38:24,532 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,532 [DEBUG] [DividerAmbassador] divider begins executing iteration5 for worker2
# 2023-07-05 22:38:24,534 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 5
# 2023-07-05 22:38:24,534 [DEBUG] [DividerAmbassador] divider begins executing iteration5 for worker3
# 2023-07-05 22:38:24,536 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 5
# 2023-07-05 22:38:24,537 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 5
# 2023-07-05 22:38:24,539 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,540 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_5_trained.pkl from worker1
# 2023-07-05 22:38:24,543 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,544 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,546 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_5_trained.pkl from worker2
# 2023-07-05 22:38:24,546 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_5_trained.pkl from worker3
# 2023-07-05 22:38:24,548 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_5_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,550 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_5_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,551 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_5_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,553 [DEBUG] [MachineLearning] Iteration 5/20 complete.
# 2023-07-05 22:38:24,553 [DEBUG] [MachineLearning] Starting iteration 6/20
# 2023-07-05 22:38:24,555 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,555 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,555 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,556 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration6 to worker1
# 2023-07-05 22:38:24,558 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration6 to worker2
# 2023-07-05 22:38:24,559 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration6 to worker3
# 2023-07-05 22:38:24,560 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,560 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,561 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,564 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,565 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,565 [DEBUG] [DividerAmbassador] divider begins executing iteration6 for worker1
# 2023-07-05 22:38:24,566 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,567 [DEBUG] [DividerAmbassador] divider begins executing iteration6 for worker2
# 2023-07-05 22:38:24,568 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 6
# 2023-07-05 22:38:24,568 [DEBUG] [DividerAmbassador] divider begins executing iteration6 for worker3
# 2023-07-05 22:38:24,570 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 6
# 2023-07-05 22:38:24,571 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 6
# 2023-07-05 22:38:24,572 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,574 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_6_trained.pkl from worker1
# 2023-07-05 22:38:24,575 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,575 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,577 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_6_trained.pkl from worker2
# 2023-07-05 22:38:24,578 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_6_trained.pkl from worker3
# 2023-07-05 22:38:24,579 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_6_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,581 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_6_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,582 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_6_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,584 [DEBUG] [MachineLearning] Iteration 6/20 complete.
# 2023-07-05 22:38:24,585 [DEBUG] [MachineLearning] Starting iteration 7/20
# 2023-07-05 22:38:24,586 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,587 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,587 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,588 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration7 to worker1
# 2023-07-05 22:38:24,589 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration7 to worker2
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-05 22:38:24,589 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration7 to worker3
# 2023-07-05 22:38:24,590 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,591 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,592 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,595 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,595 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,596 [DEBUG] [DividerAmbassador] divider begins executing iteration7 for worker2
# 2023-07-05 22:38:24,597 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,597 [DEBUG] [DividerAmbassador] divider begins executing iteration7 for worker1
# 2023-07-05 22:38:24,598 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 7
# 2023-07-05 22:38:24,598 [DEBUG] [DividerAmbassador] divider begins executing iteration7 for worker3
# 2023-07-05 22:38:24,600 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 7
# 2023-07-05 22:38:24,601 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 7
# 2023-07-05 22:38:24,603 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,603 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_7_trained.pkl from worker2
# 2023-07-05 22:38:24,606 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,606 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,607 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_7_trained.pkl from worker1
# 2023-07-05 22:38:24,608 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_7_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,608 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_7_trained.pkl from worker3
# 2023-07-05 22:38:24,611 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_7_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,612 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_7_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,614 [DEBUG] [MachineLearning] Iteration 7/20 complete.
# 2023-07-05 22:38:24,615 [DEBUG] [MachineLearning] Starting iteration 8/20
# 2023-07-05 22:38:24,616 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,616 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,616 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,618 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration8 to worker1
# 2023-07-05 22:38:24,619 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration8 to worker2
# 2023-07-05 22:38:24,619 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration8 to worker3
# 2023-07-05 22:38:24,620 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,621 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,621 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,624 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,625 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,626 [DEBUG] [DividerAmbassador] divider begins executing iteration8 for worker1
# 2023-07-05 22:38:24,627 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,627 [DEBUG] [DividerAmbassador] divider begins executing iteration8 for worker2
# 2023-07-05 22:38:24,629 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 8
# 2023-07-05 22:38:24,629 [DEBUG] [DividerAmbassador] divider begins executing iteration8 for worker3
# 2023-07-05 22:38:24,631 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 8
# 2023-07-05 22:38:24,631 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,632 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 8
# 2023-07-05 22:38:24,634 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_8_trained.pkl from worker1
# 2023-07-05 22:38:24,635 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,637 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,638 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_8_trained.pkl from worker2
# 2023-07-05 22:38:24,639 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_8_trained.pkl from worker3
# 2023-07-05 22:38:24,640 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_8_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,642 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_8_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,643 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_8_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,645 [DEBUG] [MachineLearning] Iteration 8/20 complete.
# 2023-07-05 22:38:24,646 [DEBUG] [MachineLearning] Starting iteration 9/20
# 2023-07-05 22:38:24,647 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,647 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,648 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,649 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration9 to worker1
# 2023-07-05 22:38:24,650 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration9 to worker2
# 2023-07-05 22:38:24,651 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration9 to worker3
# 2023-07-05 22:38:24,652 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,652 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,653 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,655 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,657 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,658 [DEBUG] [DividerAmbassador] divider begins executing iteration9 for worker1
# 2023-07-05 22:38:24,658 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,659 [DEBUG] [DividerAmbassador] divider begins executing iteration9 for worker2
# 2023-07-05 22:38:24,660 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 9
# 2023-07-05 22:38:24,661 [DEBUG] [DividerAmbassador] divider begins executing iteration9 for worker3
# 2023-07-05 22:38:24,662 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 9
# 2023-07-05 22:38:24,664 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,664 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 9
# 2023-07-05 22:38:24,666 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_9_trained.pkl from worker1
# 2023-07-05 22:38:24,667 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,670 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,671 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_9_trained.pkl from worker2
# 2023-07-05 22:38:24,672 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_9_trained.pkl from worker3
# 2023-07-05 22:38:24,672 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_9_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,675 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_9_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,676 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_9_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,678 [DEBUG] [MachineLearning] Iteration 9/20 complete.
# 2023-07-05 22:38:24,678 [DEBUG] [MachineLearning] Starting iteration 10/20
# 2023-07-05 22:38:24,680 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,680 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,681 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,682 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration10 to worker1
# 2023-07-05 22:38:24,683 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration10 to worker2
# 2023-07-05 22:38:24,683 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration10 to worker3
# 2023-07-05 22:38:24,684 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,685 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,686 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,688 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,690 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,690 [DEBUG] [DividerAmbassador] divider begins executing iteration10 for worker1
# 2023-07-05 22:38:24,691 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,692 [DEBUG] [DividerAmbassador] divider begins executing iteration10 for worker2
# 2023-07-05 22:38:24,693 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 10
# 2023-07-05 22:38:24,694 [DEBUG] [DividerAmbassador] divider begins executing iteration10 for worker3
# 2023-07-05 22:38:24,696 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 10
# 2023-07-05 22:38:24,696 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,697 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 10
# 2023-07-05 22:38:24,698 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_10_trained.pkl from worker1
# 2023-07-05 22:38:24,699 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,702 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,703 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_10_trained.pkl from worker2
# 2023-07-05 22:38:24,704 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_10_trained.pkl from worker3
# 2023-07-05 22:38:24,704 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_10_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,706 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_10_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,708 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_10_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,709 [DEBUG] [MachineLearning] Iteration 10/20 complete.
# 2023-07-05 22:38:24,710 [DEBUG] [MachineLearning] Starting iteration 11/20
# 2023-07-05 22:38:24,712 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,712 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,713 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,714 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration11 to worker1
# 2023-07-05 22:38:24,714 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration11 to worker2
# 2023-07-05 22:38:24,715 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration11 to worker3
# 2023-07-05 22:38:24,716 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,717 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,718 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,721 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,721 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,723 [DEBUG] [DividerAmbassador] divider begins executing iteration11 for worker1
# 2023-07-05 22:38:24,724 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,724 [DEBUG] [DividerAmbassador] divider begins executing iteration11 for worker2
# 2023-07-05 22:38:24,725 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 11
# 2023-07-05 22:38:24,726 [DEBUG] [DividerAmbassador] divider begins executing iteration11 for worker3
# 2023-07-05 22:38:24,728 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 11
# 2023-07-05 22:38:24,729 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,729 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 11
# 2023-07-05 22:38:24,731 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_11_trained.pkl from worker1
# 2023-07-05 22:38:24,732 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,733 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,735 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_11_trained.pkl from worker2
# 2023-07-05 22:38:24,736 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_11_trained.pkl from worker3
# 2023-07-05 22:38:24,736 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_11_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,739 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_11_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,739 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_11_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,741 [DEBUG] [MachineLearning] Iteration 11/20 complete.
# 2023-07-05 22:38:24,742 [DEBUG] [MachineLearning] Starting iteration 12/20
# 2023-07-05 22:38:24,743 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,744 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,744 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,745 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration12 to worker1
# 2023-07-05 22:38:24,746 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration12 to worker2
# 2023-07-05 22:38:24,747 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration12 to worker3
# 2023-07-05 22:38:24,747 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,748 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,748 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,751 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,752 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,753 [DEBUG] [DividerAmbassador] divider begins executing iteration12 for worker1
# 2023-07-05 22:38:24,754 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,754 [DEBUG] [DividerAmbassador] divider begins executing iteration12 for worker2
# 2023-07-05 22:38:24,755 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 12
# 2023-07-05 22:38:24,756 [DEBUG] [DividerAmbassador] divider begins executing iteration12 for worker3
# 2023-07-05 22:38:24,757 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 12
# 2023-07-05 22:38:24,759 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,760 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 12
# 2023-07-05 22:38:24,761 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_12_trained.pkl from worker1
# 2023-07-05 22:38:24,762 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,764 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,764 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_12_trained.pkl from worker2
# 2023-07-05 22:38:24,765 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_12_trained.pkl from worker3
# 2023-07-05 22:38:24,766 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_12_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,769 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_12_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,770 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_12_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,772 [DEBUG] [MachineLearning] Iteration 12/20 complete.
# 2023-07-05 22:38:24,772 [DEBUG] [MachineLearning] Starting iteration 13/20
# 2023-07-05 22:38:24,774 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,774 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,775 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,776 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration13 to worker1
# 2023-07-05 22:38:24,777 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration13 to worker2
# 2023-07-05 22:38:24,778 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration13 to worker3
# 2023-07-05 22:38:24,779 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,780 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,780 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,783 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,785 [DEBUG] [DividerAmbassador] divider begins executing iteration13 for worker1
# 2023-07-05 22:38:24,786 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,786 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,787 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 13
# 2023-07-05 22:38:24,788 [DEBUG] [DividerAmbassador] divider begins executing iteration13 for worker2
# 2023-07-05 22:38:24,788 [DEBUG] [DividerAmbassador] divider begins executing iteration13 for worker3
# 2023-07-05 22:38:24,790 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,791 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 13
# 2023-07-05 22:38:24,792 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 13
# 2023-07-05 22:38:24,793 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_13_trained.pkl from worker1
# 2023-07-05 22:38:24,795 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,796 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,797 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_13_trained.pkl from worker2
# 2023-07-05 22:38:24,798 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_13_trained.pkl from worker3
# 2023-07-05 22:38:24,798 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_13_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,801 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_13_trained.pkl from worker2 successfully
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-05 22:38:24,803 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_13_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,805 [DEBUG] [MachineLearning] Iteration 13/20 complete.
# 2023-07-05 22:38:24,805 [DEBUG] [MachineLearning] Starting iteration 14/20
# 2023-07-05 22:38:24,806 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,807 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,807 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,808 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration14 to worker1
# 2023-07-05 22:38:24,809 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration14 to worker2
# 2023-07-05 22:38:24,811 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration14 to worker3
# 2023-07-05 22:38:24,811 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,812 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,813 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,815 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,816 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,817 [DEBUG] [DividerAmbassador] divider begins executing iteration14 for worker1
# 2023-07-05 22:38:24,818 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,819 [DEBUG] [DividerAmbassador] divider begins executing iteration14 for worker2
# 2023-07-05 22:38:24,820 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 14
# 2023-07-05 22:38:24,820 [DEBUG] [DividerAmbassador] divider begins executing iteration14 for worker3
# 2023-07-05 22:38:24,822 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 14
# 2023-07-05 22:38:24,823 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,823 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 14
# ...
# 2023-07-05 22:38:24,882 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 16
# 2023-07-05 22:38:24,882 [DEBUG] [DividerAmbassador] divider begins executing iteration16 for worker3
# 2023-07-05 22:38:24,884 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 16
# 2023-07-05 22:38:24,885 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,886 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 16
# 2023-07-05 22:38:24,887 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_16_trained.pkl from worker1
# 2023-07-05 22:38:24,888 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,890 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,891 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_16_trained.pkl from worker2
# 2023-07-05 22:38:24,892 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_16_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,892 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_16_trained.pkl from worker3
# 2023-07-05 22:38:24,895 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_16_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,896 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_16_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,897 [DEBUG] [MachineLearning] Iteration 16/20 complete.
# 2023-07-05 22:38:24,898 [DEBUG] [MachineLearning] Starting iteration 17/20
# 2023-07-05 22:38:24,899 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,899 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,900 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,902 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration17 to worker1
# 2023-07-05 22:38:24,903 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration17 to worker2
# 2023-07-05 22:38:24,904 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration17 to worker3
# 2023-07-05 22:38:24,904 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,905 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,906 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,908 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,911 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,912 [DEBUG] [DividerAmbassador] divider begins executing iteration17 for worker1
# 2023-07-05 22:38:24,912 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,913 [DEBUG] [DividerAmbassador] divider begins executing iteration17 for worker2
# 2023-07-05 22:38:24,914 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 17
# 2023-07-05 22:38:24,915 [DEBUG] [DividerAmbassador] divider begins executing iteration17 for worker3
# 2023-07-05 22:38:24,916 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 17
# 2023-07-05 22:38:24,918 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,919 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 17
# 2023-07-05 22:38:24,920 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_17_trained.pkl from worker1
# 2023-07-05 22:38:24,921 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,922 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,924 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_17_trained.pkl from worker2
# 2023-07-05 22:38:24,924 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_17_trained.pkl from worker3
# 2023-07-05 22:38:24,925 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_17_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,928 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_17_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,928 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_17_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,930 [DEBUG] [MachineLearning] Iteration 17/20 complete.
# 2023-07-05 22:38:24,931 [DEBUG] [MachineLearning] Starting iteration 18/20
# 2023-07-05 22:38:24,932 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,932 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,932 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,934 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration18 to worker1
# 2023-07-05 22:38:24,935 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration18 to worker2
# 2023-07-05 22:38:24,936 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration18 to worker3
# 2023-07-05 22:38:24,937 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,937 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,938 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,941 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,942 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,943 [DEBUG] [DividerAmbassador] divider begins executing iteration18 for worker1
# 2023-07-05 22:38:24,944 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,945 [DEBUG] [DividerAmbassador] divider begins executing iteration18 for worker2
# 2023-07-05 22:38:24,946 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 18
# 2023-07-05 22:38:24,946 [DEBUG] [DividerAmbassador] divider begins executing iteration18 for worker3
# 2023-07-05 22:38:24,948 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 18
# 2023-07-05 22:38:24,949 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,950 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 18
# 2023-07-05 22:38:24,951 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_18_trained.pkl from worker1
# 2023-07-05 22:38:24,953 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,955 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,956 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_18_trained.pkl from worker2
# 2023-07-05 22:38:24,957 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_18_trained.pkl from worker3
# 2023-07-05 22:38:24,957 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_18_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,960 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_18_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,962 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_18_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,964 [DEBUG] [MachineLearning] Iteration 18/20 complete.
# 2023-07-05 22:38:24,964 [DEBUG] [MachineLearning] Starting iteration 19/20
# 2023-07-05 22:38:24,966 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,966 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,967 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:24,969 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration19 to worker1
# 2023-07-05 22:38:24,969 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration19 to worker2
# 2023-07-05 22:38:24,970 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration19 to worker3
# 2023-07-05 22:38:24,971 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:24,972 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:24,972 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:24,974 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:24,976 [DEBUG] [DividerAmbassador] divider begins executing iteration19 for worker1
# 2023-07-05 22:38:24,977 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:24,978 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:24,979 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 19
# 2023-07-05 22:38:24,980 [DEBUG] [DividerAmbassador] divider begins executing iteration19 for worker2
# 2023-07-05 22:38:24,981 [DEBUG] [DividerAmbassador] divider begins executing iteration19 for worker3
# 2023-07-05 22:38:24,982 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,983 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 19
# 2023-07-05 22:38:24,984 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 19
# 2023-07-05 22:38:24,985 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_19_trained.pkl from worker1
# 2023-07-05 22:38:24,987 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,989 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_19_trained.pkl from worker2
# 2023-07-05 22:38:24,989 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:24,990 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_19_trained.pkl from worker1 successfully
# 2023-07-05 22:38:24,991 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_19_trained.pkl from worker3
# 2023-07-05 22:38:24,993 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_19_trained.pkl from worker2 successfully
# 2023-07-05 22:38:24,995 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_19_trained.pkl from worker3 successfully
# 2023-07-05 22:38:24,996 [DEBUG] [MachineLearning] Iteration 19/20 complete.
# 2023-07-05 22:38:24,997 [DEBUG] [MachineLearning] Starting iteration 20/20
# 2023-07-05 22:38:24,998 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:38:24,998 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 22:38:24,999 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 22:38:25,000 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration20 to worker1
# 2023-07-05 22:38:25,001 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration20 to worker2
# 2023-07-05 22:38:25,002 [DEBUG] [DividerAmbassador] divider begins will not send data in iteration20 to worker3
# 2023-07-05 22:38:25,003 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/1.pkl to worker1
# 2023-07-05 22:38:25,004 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/2.pkl to worker2
# 2023-07-05 22:38:25,004 [DEBUG] [DividerAmbassador] Sending ../../../../Rain_data/RainData/divider/3.pkl to worker3
# 2023-07-05 22:38:25,007 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:38:25,007 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 22:38:25,008 [DEBUG] [DividerAmbassador] divider begins executing iteration20 for worker1
# 2023-07-05 22:38:25,009 [DEBUG] [DividerAmbassador] divider begins executing iteration20 for worker2
# 2023-07-05 22:38:25,010 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 22:38:25,011 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 20
# 2023-07-05 22:38:25,012 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 20
# 2023-07-05 22:38:25,013 [DEBUG] [DividerAmbassador] divider begins executing iteration20 for worker3
# 2023-07-05 22:38:25,014 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:25,016 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 20
# 2023-07-05 22:38:25,017 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:25,018 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/1_20_trained.pkl from worker1
# 2023-07-05 22:38:25,020 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/2_20_trained.pkl from worker2
# 2023-07-05 22:38:25,020 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:38:25,023 [DEBUG] [DividerAmbassador] divider begins downloading ../../../../Rain_data/RainData/divider/3_20_trained.pkl from worker3
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# sending data to divider
# 2023-07-05 22:38:25,023 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/1_20_trained.pkl from worker1 successfully
# 2023-07-05 22:38:25,024 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/2_20_trained.pkl from worker2 successfully
# 2023-07-05 22:38:25,026 [DEBUG] [DividerAmbassador] Downloaded ../../../../Rain_data/RainData/divider/3_20_trained.pkl from worker3 successfully
# 2023-07-05 22:38:25,028 [DEBUG] [MachineLearning] Iteration 20/20 complete.
# 2023-07-05 22:38:25,028 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-05 22:38:25,029 [DEBUG] [Divider] Divider stopped serving
# 2023-07-05 22:38:25,030 [INFO] [Worker_50151] Worker stopped serving on port: 50151
# 2023-07-05 22:38:25,031 [INFO] [Worker_50152] Worker stopped serving on port: 50152
# 2023-07-05 22:38:25,031 [INFO] [Worker_50153] Worker stopped serving on port: 50153
# 2023-07-05 22:38:25,032 [DEBUG] [LocalProvisioner] Workers are deleted
# 2023-07-05 22:38:25,033 [INFO] [Provisioner] provisioner stopped serving

# %%
labels = model.get_labels(X)
# Out:
# [[-0.15633484  0.84779098]
#  [ 0.42264482 -0.7374192 ]]

# %%
# Plot the data (X) along with the labels as colors
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

for i in range(len(X)):
    if labels[i] == 0:
        plt.scatter(X[i, 0], X[i, 1], c='blue')
    elif labels[i] == 1:
        plt.scatter(X[i, 0], X[i, 1], c='red')
    elif labels[i] == 2:
        plt.scatter(X[i, 0], X[i, 1], c='green')

# Set labels for axes
plt.xlabel('x1')
plt.ylabel('x2')

# Show the plot
plt.show()
