# %%
import numpy as np
import sys
# sys.path.append("../../../src/")
from Rain.Rain import Rain
# sys.path.pop()
# Out:
# 2023-07-05 18:43:23.425771: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-05 18:43:24.138850: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "lazy",
      "params": {
          "num_of_workers": 1,
        "ips": ['172.190.116.144'],
        "ports": [50151]
      }
    },
  "temp_data_path": "../../../",
  "partitions": 1,
  
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-05 18:43:25,072 [ERROR] [Rain] Error in the config: Error in partitions: argument of type 'int' is not iterable
# 2023-07-05 18:43:25,074 [DEBUG] [Rain] Rain is initialized
# 2023-07-05 18:43:25,075 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-05 18:43:25,077 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-05 18:43:25,078 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-05 18:43:25,080 [DEBUG] [LazyProvisioner] Provisioner is initialized
# 2023-07-05 18:43:25,081 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-05 18:43:25,082 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-05 18:43:25,083 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-05 18:43:25,095 [INFO] [Provisioner] provisioner is serving
# 2023-07-05 18:43:25,096 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-05 18:43:25,099 [INFO] [Coordinator] coordinator is serving
# 2023-07-05 18:43:25,099 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-05 18:43:25,104 [DEBUG] [Provisioner] Received 'NumOfWorkers: 1
# ' from the coordinator to define the number of workers
# 2023-07-05 18:43:25,105 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-05 18:43:25,106 [DEBUG] [LazyProvisioner] Creating 1 workers
# 2023-07-05 18:43:25,106 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker/
# 2023-07-05 18:43:25,109 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-05 18:43:25,109 [DEBUG] [Provisioner] [Created workers]
# IPs : ['172.190.116.144'], ports: [50151], statuses: [1], IDs : [1]
# 2023-07-05 18:43:25,112 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-05 18:43:25,113 [DEBUG] [DividerProxy] Training Started
# 2023-07-05 18:43:25,116 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-05 18:43:25,117 [DEBUG] [Provisioner] Workers
# IPs : ['172.190.116.144'], ports: [50151], statuses: [1], IDs : [1]
# 2023-07-05 18:43:25,118 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-05 18:43:25,119 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-05 18:43:25,121 [DEBUG] [DividerAmbassador] 172.190.116.144:50151
# 2023-07-05 18:43:26,230 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-05 18:43:26,381 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-05 18:43:26,382 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-05 18:43:26,519 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 18:43:26,523 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-05 18:43:26,668 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 18:43:26,669 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-05 18:43:26,807 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-05 18:43:26,809 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-05 18:43:26,809 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-05 18:43:26,810 [DEBUG] [Divider] Divider stopped serving
# 2023-07-05 18:43:26,811 [DEBUG] [LazyProvisioner] Workers are deleted
# 2023-07-05 18:43:26,812 [INFO] [Provisioner] provisioner stopped serving

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 94.74%
# 2023-07-05 18:44:52,031 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-05 18:44:52,536 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-05 18:45:27,700 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-05 18:50:50,521 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-05 18:50:50,527 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-05 18:50:50,534 [DEBUG] [Coordinator] coordinator is sending workers info to divider
