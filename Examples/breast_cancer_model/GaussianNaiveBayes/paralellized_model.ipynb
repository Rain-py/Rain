# %%
import numpy as np
import sys
# sys.path.append("../../../src/")
from Rain.Rain import Rain
# sys.path.pop()

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "cloud",
      "params": {
          "num_of_workers": 1,
          "subscription_id": "a7ef3688-af58-4835-953c-e51f219fbd0f", # Mostafa's ID
          # "subscription_id":'6e14c264-a7fc-4db4-a23a-d972c21a2d99', # Menna's ID
          # "subscription_id": '82305756-d4a0-442d-8e73-625e1ced2113', # Nada's ID
          "location": 'eastus'
      }  
    },
  "temp_data_path": "../../../",
  "partitions": 3,
  "chunk_size": 1024*1024,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-07 23:14:19,648 [DEBUG] [Rain] Rain is initialized
# 2023-07-07 23:14:19,650 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-07 23:14:19,651 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-07 23:14:19,652 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-07 23:14:19,696 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/prov/
# 2023-07-07 23:14:19,698 [DEBUG] [CloudProvisioner] Provisioner is initialized
# 2023-07-07 23:14:19,699 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-07 23:14:19,701 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-07 23:14:19,702 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-07 23:14:19,713 [INFO] [Provisioner] provisioner is serving
# 2023-07-07 23:14:19,714 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-07 23:14:19,716 [INFO] [Coordinator] coordinator is serving
# 2023-07-07 23:14:19,717 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-07 23:14:19,722 [DEBUG] [Provisioner] Received 'NumOfWorkers: 1
# ' from the coordinator to define the number of workers
# 2023-07-07 23:14:19,724 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-07 23:14:19,726 [DEBUG] [Coordinator] coordinator is sending the number of workers to provisioner
# 2023-07-07 23:14:19,728 [DEBUG] [Provisioner] Provision requested the coordinator to get the number of workers
# 2023-07-07 23:14:19,728 [DEBUG] [CloudProvisioner] Setup the networking for the workers
# 2023-07-07 23:14:25,099 [DEBUG] [CloudProvisioner] Created resource group: Rain-resourcegroup
# 2023-07-07 23:14:43,373 [DEBUG] [CloudProvisioner] Created virtual network: Rain-vnet
# 2023-07-07 23:14:48,411 [DEBUG] [CloudProvisioner] Created network security group: Rain-nic-nsg
# 2023-07-07 23:14:48,415 [DEBUG] [CloudProvisioner] Network setup completed
# 2023-07-07 23:14:48,416 [DEBUG] [CloudProvisioner] Creating 1 worker
# 2023-07-07 23:14:48,473 [DEBUG] [CloudProvisioner] Created SSH key pair at ../../..//RainData/prov//private_key.pem and ../../..//RainData/prov//public_key.pem
# 2023-07-07 23:14:48,474 [DEBUG] [CloudProvisioner] Creating worker Rain-vm1
# 2023-07-07 23:14:52,689 [DEBUG] [CloudProvisioner] Created public IP address: Rain-nic-Rain-vm1-ip
# 2023-07-07 23:14:57,316 [DEBUG] [CloudProvisioner] Created network interface: Rain-nic-Rain-vm1
# 2023-07-07 23:15:39,997 [DEBUG] [CloudProvisioner] Created virtual machine: Rain-vm1
# 2023-07-07 23:15:39,998 [INFO] [CloudProvisioner] Created worker Rain-vm1
# 2023-07-07 23:18:14,745 [INFO] [CloudProvisioner] Worker 1 is up on 20.120.109.103:50151
# 2023-07-07 23:18:14,749 [DEBUG] [Provisioner] [Created workers]
# IPs : ['20.120.109.103'], ports: [50151], statuses: [1], IDs : [1]
# 2023-07-07 23:18:14,751 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-07 23:18:14,752 [DEBUG] [DividerProxy] Training Started
# 2023-07-07 23:18:14,753 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-07 23:18:14,755 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-07 23:18:14,756 [DEBUG] [Provisioner] Workers
# IPs : ['20.120.109.103'], ports: [50151], statuses: [1], IDs : [1]
# 2023-07-07 23:18:14,757 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-07 23:18:14,758 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-07 23:18:14,759 [DEBUG] [DividerAmbassador] 20.120.109.103:50151
# 2023-07-07 23:18:14,759 [DEBUG] [MachineLearning] Error in training the model: list index out of range
# 2023-07-07 23:18:14,760 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-07 23:18:14,761 [DEBUG] [Divider] Divider stopped serving

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 y_pred = model.predict(X_test)
#       2 print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
#
# AttributeError: 'NoneType' object has no attribute 'predict'
# 2023-07-07 23:18:15,425 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-07 23:18:15,652 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 1 after sending y_train
# 2023-07-07 23:18:15,657 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-07 23:18:15,919 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-07 23:18:15,921 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-07 23:18:16,177 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-07 23:18:16,178 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-07 23:18:16,492 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully

# %%
del rain
# Out:
# 2023-07-07 23:18:42,088 [DEBUG] [CloudProvisioner] Deleting virtual machine: Rain-vm1
# 2023-07-07 23:19:15,467 [DEBUG] [CloudProvisioner] Deleting network interface: Rain-nic-Rain-vm1
# 2023-07-07 23:19:17,251 [DEBUG] [CloudProvisioner] Deleting public IP address: Rain-nic-Rain-vm1-ip
# 2023-07-07 23:19:18,041 [DEBUG] [CloudProvisioner] Deleting network security group: Rain-nic-nsg
# 2023-07-07 23:19:18,839 [DEBUG] [CloudProvisioner] Deleting virtual network: Rain-vnet
# 2023-07-07 23:19:29,840 [DEBUG] [CloudProvisioner] Deleting resource group: Rain-resourcegroup
# 2023-07-07 23:21:48,338 [DEBUG] [CloudProvisioner] Networking cleanup completed
# 2023-07-07 23:21:48,341 [DEBUG] [CloudProvisioner] Workers are deleted
# 2023-07-07 23:21:48,343 [INFO] [Provisioner] provisioner stopped serving
