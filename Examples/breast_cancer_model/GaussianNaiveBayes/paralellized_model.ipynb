# %%
import numpy as np
import sys
# sys.path.append("../../../src/")
from Rain.Rain import Rain
# sys.path.pop()

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "cloud",
      "params": {
          "num_of_workers": 1,
          "subscription_id": "a7ef3688-af58-4835-953c-e51f219fbd0f", # Mostafa's ID
          # "subscription_id":'6e14c264-a7fc-4db4-a23a-d972c21a2d99', # Menna's ID
          # "subscription_id": '82305756-d4a0-442d-8e73-625e1ced2113', # Nada's ID
          "location": 'eastus'
      }  
    },
  "temp_data_path": "../../../",
  "partitions": 3,
  "chunk_size": 1024*1024,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-07 17:09:18,626 [DEBUG] [Rain] Rain is initialized
# 2023-07-07 17:09:18,627 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-07 17:09:18,628 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-07 17:09:18,629 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-07 17:09:18,680 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/prov/
# 2023-07-07 17:09:18,681 [DEBUG] [CloudProvisioner] Provisioner is initialized
# 2023-07-07 17:09:18,683 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-07 17:09:18,684 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-07 17:09:18,685 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-07 17:09:18,696 [INFO] [Provisioner] provisioner is serving
# 2023-07-07 17:09:18,697 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-07 17:09:18,698 [INFO] [Coordinator] coordinator is serving
# 2023-07-07 17:09:18,699 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-07 17:09:18,704 [DEBUG] [Provisioner] Received 'NumOfWorkers: 1
# ' from the coordinator to define the number of workers
# 2023-07-07 17:09:18,705 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-07 17:09:18,707 [DEBUG] [Coordinator] coordinator is sending the number of workers to provisioner
# 2023-07-07 17:09:18,709 [DEBUG] [Provisioner] Provision requested the coordinator to get the number of workers
# 2023-07-07 17:09:18,709 [DEBUG] [CloudProvisioner] Setup the networking for the workers
# 2023-07-07 17:09:21,536 [DEBUG] [CloudProvisioner] Created resource group: Rain-resourcegroup
# 2023-07-07 17:09:24,868 [DEBUG] [CloudProvisioner] Created virtual network: Rain-vnet
# 2023-07-07 17:09:26,117 [DEBUG] [CloudProvisioner] Created network security group: Rain-nic-nsg
# 2023-07-07 17:09:26,121 [DEBUG] [CloudProvisioner] Network setup completed
# 2023-07-07 17:09:26,123 [DEBUG] [CloudProvisioner] Creating 1 worker
# 2023-07-07 17:09:26,150 [DEBUG] [CloudProvisioner] Created SSH key pair at ../../..//RainData/prov//private_key.pem and ../../..//RainData/prov//public_key.pem
# 2023-07-07 17:09:26,151 [DEBUG] [CloudProvisioner] Creating worker Rain-vm1
# 2023-07-07 17:09:29,185 [DEBUG] [CloudProvisioner] Created public IP address: Rain-nic-Rain-vm1-ip
# 2023-07-07 17:09:31,124 [DEBUG] [CloudProvisioner] Created network interface: Rain-nic-Rain-vm1
# 2023-07-07 17:10:42,323 [DEBUG] [CloudProvisioner] Created virtual machine: Rain-vm1
# 2023-07-07 17:10:42,328 [INFO] [CloudProvisioner] Created worker Rain-vm1

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
