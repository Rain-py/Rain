# %%
import numpy as np
import sys
sys.path.append("../../../src/")
from Rain.Rain import Rain
sys.path.pop()
# Out:
# '../../../src/'

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "local",
      "params": {}
    },
  "temp_data_path": "../../../../",
  "partitions": 3,
  "num_of_workers": 3,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-04 20:38:00,057 [DEBUG] [Rain] Rain is initialized
# 2023-07-04 20:38:00,057 [DEBUG] [Rain] Rain is initialized
# 2023-07-04 20:38:00,057 [DEBUG] [Rain] Rain is initialized
# 2023-07-04 20:38:00,057 [DEBUG] [Rain] Rain is initialized
# 2023-07-04 20:38:00,100 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-04 20:38:00,100 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-04 20:38:00,100 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-04 20:38:00,100 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-04 20:38:00,118 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/coord/
# 2023-07-04 20:38:00,125 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-04 20:38:00,125 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-04 20:38:00,125 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-04 20:38:00,125 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-04 20:38:00,135 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-04 20:38:00,135 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-04 20:38:00,135 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-04 20:38:00,135 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-04 20:38:00,158 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/divider/
# 2023-07-04 20:38:00,178 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/divider/
# 2023-07-04 20:38:00,200 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/divider/
# 2023-07-04 20:38:00,210 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:00,210 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:00,210 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:00,210 [DEBUG] [DividerAmbassador] divider ambassador stopped serving

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-04 20:38:00,239 [DEBUG] [Rain] Creating workers
# 2023-07-04 20:38:00,239 [DEBUG] [Rain] Creating workers
# 2023-07-04 20:38:00,239 [DEBUG] [Rain] Creating workers
# 2023-07-04 20:38:00,239 [DEBUG] [Rain] Creating workers
# 2023-07-04 20:38:00,256 [INFO] [Provisioner] provisioner is serving
# 2023-07-04 20:38:00,256 [INFO] [Provisioner] provisioner is serving
# 2023-07-04 20:38:00,256 [INFO] [Provisioner] provisioner is serving
# 2023-07-04 20:38:00,256 [INFO] [Provisioner] provisioner is serving
# 2023-07-04 20:38:00,270 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-04 20:38:00,270 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-04 20:38:00,270 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-04 20:38:00,270 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-04 20:38:00,287 [INFO] [Coordinator] coordinator is serving
# 2023-07-04 20:38:00,287 [INFO] [Coordinator] coordinator is serving
# 2023-07-04 20:38:00,287 [INFO] [Coordinator] coordinator is serving
# 2023-07-04 20:38:00,287 [INFO] [Coordinator] coordinator is serving
# 2023-07-04 20:38:00,299 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-04 20:38:00,299 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-04 20:38:00,299 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-04 20:38:00,299 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-04 20:38:00,316 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-04 20:38:00,316 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-04 20:38:00,316 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-04 20:38:00,316 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-04 20:38:00,328 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-04 20:38:00,328 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-04 20:38:00,328 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-04 20:38:00,328 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-04 20:38:00,338 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-04 20:38:00,338 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-04 20:38:00,338 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-04 20:38:00,338 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-04 20:38:00,357 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/worker/
# 2023-07-04 20:38:00,369 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-04 20:38:00,369 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-04 20:38:00,369 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-04 20:38:00,369 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-04 20:38:00,391 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/worker/
# 2023-07-04 20:38:00,405 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-04 20:38:00,405 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-04 20:38:00,405 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-04 20:38:00,405 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-04 20:38:00,427 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/worker/
# 2023-07-04 20:38:00,445 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-04 20:38:00,445 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-04 20:38:00,445 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-04 20:38:00,445 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-04 20:38:00,459 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 20:38:00,459 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 20:38:00,459 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 20:38:00,459 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 20:38:00,473 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-04 20:38:00,473 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-04 20:38:00,473 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-04 20:38:00,473 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-04 20:38:00,484 [DEBUG] [DividerProxy] Training Started
# 2023-07-04 20:38:00,484 [DEBUG] [DividerProxy] Training Started
# 2023-07-04 20:38:00,484 [DEBUG] [DividerProxy] Training Started
# 2023-07-04 20:38:00,484 [DEBUG] [DividerProxy] Training Started
# 2023-07-04 20:38:00,505 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-04 20:38:00,505 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-04 20:38:00,505 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-04 20:38:00,505 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-04 20:38:00,517 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 20:38:00,517 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 20:38:00,517 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 20:38:00,517 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 20:38:00,532 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-04 20:38:00,532 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-04 20:38:00,532 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-04 20:38:00,532 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-04 20:38:00,543 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-04 20:38:00,543 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-04 20:38:00,543 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-04 20:38:00,543 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-04 20:38:00,567 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 20:38:00,571 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 20:38:00,575 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 20:38:00,567 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 20:38:00,567 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 20:38:00,571 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 20:38:00,571 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 20:38:00,567 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 20:38:00,575 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 20:38:00,571 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 20:38:00,575 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 20:38:00,575 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 20:38:00,690 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,690 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,690 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,694 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,690 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,694 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,694 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,694 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,708 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,708 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,708 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,708 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 20:38:00,741 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,746 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,741 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,746 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,741 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,746 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,741 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,746 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,757 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/1.pkl to worker1
# 2023-07-04 20:38:00,764 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/2.pkl to worker2
# 2023-07-04 20:38:00,757 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/1.pkl to worker1
# 2023-07-04 20:38:00,764 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/2.pkl to worker2
# 2023-07-04 20:38:00,757 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/1.pkl to worker1
# 2023-07-04 20:38:00,764 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/2.pkl to worker2
# 2023-07-04 20:38:00,757 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/1.pkl to worker1
# 2023-07-04 20:38:00,764 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/2.pkl to worker2
# 2023-07-04 20:38:00,779 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,779 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,779 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,779 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 20:38:00,789 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/3.pkl to worker3
# 2023-07-04 20:38:00,789 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/3.pkl to worker3
# 2023-07-04 20:38:00,789 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/3.pkl to worker3
# 2023-07-04 20:38:00,789 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/3.pkl to worker3
# 2023-07-04 20:38:00,805 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 20:38:00,806 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 20:38:00,805 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 20:38:00,806 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 20:38:00,805 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 20:38:00,806 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 20:38:00,805 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 20:38:00,814 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-04 20:38:00,806 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 20:38:00,814 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-04 20:38:00,817 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-04 20:38:00,814 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-04 20:38:00,817 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-04 20:38:00,814 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-04 20:38:00,822 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 20:38:00,817 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-04 20:38:00,817 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-04 20:38:00,822 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 20:38:00,822 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 20:38:00,831 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-04 20:38:00,831 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-04 20:38:00,822 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 20:38:00,831 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-04 20:38:00,836 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-04 20:38:00,836 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-04 20:38:00,831 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-04 20:38:00,836 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-04 20:38:00,836 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-04 20:38:00,847 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-04 20:38:00,847 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-04 20:38:00,847 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-04 20:38:00,847 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-04 20:38:00,887 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,887 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,895 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,887 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,895 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,887 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,895 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,904 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-04 20:38:00,904 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-04 20:38:00,895 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,904 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-04 20:38:00,915 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-04 20:38:00,904 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-04 20:38:00,918 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,915 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-04 20:38:00,915 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-04 20:38:00,918 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,915 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-04 20:38:00,918 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,918 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 20:38:00,932 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-04 20:38:00,932 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-04 20:38:00,932 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-04 20:38:00,932 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-04 20:38:00,943 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-04 20:38:00,943 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-04 20:38:00,943 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-04 20:38:00,943 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-04 20:38:00,961 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-04 20:38:00,961 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-04 20:38:00,961 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-04 20:38:00,961 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-04 20:38:00,975 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-04 20:38:00,975 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-04 20:38:00,975 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-04 20:38:00,975 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-04 20:38:01,008 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-04 20:38:01,008 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-04 20:38:01,008 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-04 20:38:01,008 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-04 20:38:01,019 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:01,019 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:01,019 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:01,019 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:01,027 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 20:38:01,027 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 20:38:01,027 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 20:38:01,027 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 20:38:01,033 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:01,033 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:01,033 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:01,033 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 20:38:01,040 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 20:38:01,040 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 20:38:01,040 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 20:38:01,040 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 20:38:01,045 [INFO] [Provisioner] provisioner stopped serving
# 2023-07-04 20:38:01,045 [INFO] [Provisioner] provisioner stopped serving
# 2023-07-04 20:38:01,045 [INFO] [Provisioner] provisioner stopped serving
# 2023-07-04 20:38:01,045 [INFO] [Provisioner] provisioner stopped serving
# sending data to divider
# sending data to divider

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 92.98%
