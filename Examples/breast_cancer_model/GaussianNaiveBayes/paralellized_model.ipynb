# %%
import numpy as np
import sys
# sys.path.append("../../../src/")
from Rain.Rain import Rain
# sys.path.pop()

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "local",
      "params": {}
    },
  "temp_data_path": "../../../",
  "partitions": 3,
  "num_of_workers": 3,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-04 22:46:34,601 [DEBUG] [Rain] Rain is initialized
# 2023-07-04 22:46:34,602 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-04 22:46:34,604 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-04 22:46:34,605 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-04 22:46:34,606 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-04 22:46:34,607 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-04 22:46:34,608 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-04 22:46:34,610 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-04 22:46:34,616 [DEBUG] [Rain] Creating workers
# 2023-07-04 22:46:34,621 [INFO] [Provisioner] provisioner is serving
# 2023-07-04 22:46:34,622 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-04 22:46:34,624 [INFO] [Coordinator] coordinator is serving
# 2023-07-04 22:46:34,625 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-04 22:46:34,629 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-04 22:46:34,630 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-04 22:46:34,631 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-04 22:46:34,632 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker/
# 2023-07-04 22:46:34,634 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-04 22:46:34,635 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker/
# 2023-07-04 22:46:34,637 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-04 22:46:34,638 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker/
# 2023-07-04 22:46:34,640 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-04 22:46:34,641 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 22:46:34,643 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-04 22:46:34,644 [DEBUG] [DividerProxy] Training Started
# 2023-07-04 22:46:34,647 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-04 22:46:34,648 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 22:46:34,649 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-04 22:46:34,651 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-04 22:46:34,653 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 22:46:34,654 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 22:46:34,654 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 22:46:34,663 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 22:46:34,664 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 22:46:34,666 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-04 22:46:34,668 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 22:46:34,668 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 22:46:34,670 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-04 22:46:34,671 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-04 22:46:34,672 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-04 22:46:34,674 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-04 22:46:34,675 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 22:46:34,675 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 22:46:34,677 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-04 22:46:34,678 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-04 22:46:34,680 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 22:46:34,681 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-04 22:46:34,692 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 22:46:34,693 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-04 22:46:34,696 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-04 22:46:34,697 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 22:46:34,698 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-04 22:46:34,702 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-04 22:46:34,704 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-04 22:46:34,706 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-04 22:46:34,708 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-04 22:46:34,710 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-04 22:46:34,712 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 22:46:34,713 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 22:46:34,714 [INFO] [Provisioner] provisioner stopped serving

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 94.74%
