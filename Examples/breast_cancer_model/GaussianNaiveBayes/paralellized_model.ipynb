# %%
import numpy as np
import sys
sys.path.append("../../../src/")
from Rain.Rain import Rain
sys.path.pop()
# Out:
# '../../../src/'

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "local",
      "params": {
          "num_of_workers": 3,
          "subscription_id": "a7ef3688-af58-4835-953c-e51f219fbd0f", # Mostafa's ID
          # "subscription_id":'6e14c264-a7fc-4db4-a23a-d972c21a2d99', # Menna's ID
          # "subscription_id": '82305756-d4a0-442d-8e73-625e1ced2113', # Nada's ID
          "location": 'eastus'
      }  
    },
  "temp_data_path": "../../../",
  "partitions": 3,
  "chunk_size": 1024*1024,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-08 12:05:09,365 [DEBUG] [Rain] Rain is initialized
# 2023-07-08 12:05:09,365 [DEBUG] [Rain] Rain is initialized
# 2023-07-08 12:05:09,375 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-08 12:05:09,375 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-08 12:05:09,383 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-08 12:05:09,388 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-08 12:05:09,388 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-08 12:05:09,394 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-08 12:05:09,394 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-08 12:05:09,435 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-08 12:05:09,448 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-08 12:05:09,459 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-08 12:05:09,469 [INFO] [Provisioner] provisioner is serving
# 2023-07-08 12:05:09,469 [INFO] [Provisioner] provisioner is serving
# 2023-07-08 12:05:09,472 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-08 12:05:09,472 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-08 12:05:09,474 [INFO] [Coordinator] coordinator is serving
# 2023-07-08 12:05:09,474 [INFO] [Coordinator] coordinator is serving
# 2023-07-08 12:05:09,477 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-08 12:05:09,477 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-08 12:05:09,480 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-08 12:05:09,480 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-08 12:05:09,484 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-08 12:05:09,484 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-08 12:05:09,493 [DEBUG] [Provisioner] Provision requested the coordinator to get the number of workers
# 2023-07-08 12:05:09,493 [DEBUG] [Provisioner] Provision requested the coordinator to get the number of workers
# 2023-07-08 12:05:09,495 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-08 12:05:09,495 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-08 12:05:09,503 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50151/
# 2023-07-08 12:05:09,509 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-08 12:05:09,509 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-08 12:05:09,519 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50152/
# 2023-07-08 12:05:09,527 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-08 12:05:09,527 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-08 12:05:09,535 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50153/
# 2023-07-08 12:05:09,542 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-08 12:05:09,542 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-08 12:05:09,545 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-08 12:05:09,545 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-08 12:05:09,547 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-08 12:05:09,547 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-08 12:05:09,549 [DEBUG] [DividerProxy] Training Started
# 2023-07-08 12:05:09,549 [DEBUG] [DividerProxy] Training Started
# 2023-07-08 12:05:09,557 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-08 12:05:09,557 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-08 12:05:09,559 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-08 12:05:09,559 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-08 12:05:09,562 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-08 12:05:09,562 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-08 12:05:09,565 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-08 12:05:09,565 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-08 12:05:09,575 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 12:05:09,576 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 12:05:09,575 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-08 12:05:09,576 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 12:05:09,576 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-08 12:05:09,576 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-08 12:05:09,611 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-08 12:05:09,611 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-08 12:05:09,611 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-08 12:05:09,614 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-08 12:05:09,611 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-08 12:05:09,614 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-08 12:05:09,651 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 3 after sending y_train
# 2023-07-08 12:05:09,651 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 2 after sending y_train
# 2023-07-08 12:05:09,651 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 3 after sending y_train
# 2023-07-08 12:05:09,654 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 1 after sending y_train
# 2023-07-08 12:05:09,656 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 12:05:09,651 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 2 after sending y_train
# 2023-07-08 12:05:09,658 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 12:05:09,654 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 1 after sending y_train
# 2023-07-08 12:05:09,656 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-08 12:05:09,660 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 12:05:09,658 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-08 12:05:09,660 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-08 12:05:09,679 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 12:05:09,681 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 12:05:09,679 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-08 12:05:09,681 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-08 12:05:09,684 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-08 12:05:09,684 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-08 12:05:09,684 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 12:05:09,685 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-08 12:05:09,684 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-08 12:05:09,690 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-08 12:05:09,685 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-08 12:05:09,690 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-08 12:05:09,693 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-08 12:05:09,695 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-08 12:05:09,695 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-08 12:05:09,693 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-08 12:05:09,699 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-08 12:05:09,699 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-08 12:05:09,777 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 12:05:09,777 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 12:05:09,777 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-08 12:05:09,778 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 12:05:09,777 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-08 12:05:09,783 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-08 12:05:09,778 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-08 12:05:09,785 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-08 12:05:09,783 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-08 12:05:09,786 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-08 12:05:09,785 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-08 12:05:09,786 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-08 12:05:09,803 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-08 12:05:09,805 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-08 12:05:09,803 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-08 12:05:09,807 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-08 12:05:09,805 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-08 12:05:09,807 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-08 12:05:09,823 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-08 12:05:09,823 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-08 12:05:09,825 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-08 12:05:09,825 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-08 12:05:09,828 [DEBUG] [Divider] Divider stopped serving
# 2023-07-08 12:05:09,828 [DEBUG] [Divider] Divider stopped serving
# sending data to divider
# sending data to divider
# sending data to divider

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 92.98%

# %%
del rain
# Out:
# 2023-07-08 12:05:09,886 [INFO] [Worker_50151] Worker stopped serving on port: 50151
# 2023-07-08 12:05:09,886 [INFO] [Worker_50151] Worker stopped serving on port: 50151
# 2023-07-08 12:05:09,893 [INFO] [Worker_50152] Worker stopped serving on port: 50152
# 2023-07-08 12:05:09,893 [INFO] [Worker_50152] Worker stopped serving on port: 50152
# 2023-07-08 12:05:09,896 [INFO] [Worker_50153] Worker stopped serving on port: 50153
# 2023-07-08 12:05:09,896 [INFO] [Worker_50153] Worker stopped serving on port: 50153
# 2023-07-08 12:05:09,899 [DEBUG] [LocalProvisioner] Workers are deleted
# 2023-07-08 12:05:09,899 [DEBUG] [LocalProvisioner] Workers are deleted
# 2023-07-08 12:05:09,900 [INFO] [Provisioner] provisioner stopped serving
# 2023-07-08 12:05:09,900 [INFO] [Provisioner] provisioner stopped serving
