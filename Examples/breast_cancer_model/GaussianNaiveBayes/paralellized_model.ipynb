# %%
import numpy as np
import sys
# sys.path.append("../../../src/")
from Rain.Rain import Rain
# sys.path.pop()
# Out:
# 2023-07-05 18:14:16.049949: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-05 18:14:16.883762: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "lazy",
      "params": {
          "num_of_workers": 1,
        "ips": ['172.190.116.144'],
        "ports": [50151]
      }
    },
  "temp_data_path": "../../../",
  "partitions": 1,
  
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-05 18:14:17,857 [ERROR] [Rain] Error in the config: Error in partitions: argument of type 'int' is not iterable
# 2023-07-05 18:14:17,858 [DEBUG] [Rain] Rain is initialized
# 2023-07-05 18:14:17,861 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-05 18:14:17,862 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-05 18:14:17,863 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-05 18:14:17,864 [DEBUG] [LazyProvisioner] Provisioner is initialized
# 2023-07-05 18:14:17,865 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-05 18:14:17,866 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-05 18:14:17,868 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-05 18:14:17,884 [INFO] [Provisioner] provisioner is serving
# 2023-07-05 18:14:17,885 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-05 18:14:17,889 [INFO] [Coordinator] coordinator is serving
# 2023-07-05 18:14:17,890 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-05 18:14:17,894 [DEBUG] [Provisioner] Received 'NumOfWorkers: 1
# ' from the coordinator to define the number of workers
# 2023-07-05 18:14:17,896 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-05 18:14:17,896 [DEBUG] [LazyProvisioner] Creating 1 workers
# 2023-07-05 18:14:17,897 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker/
# 2023-07-05 18:14:17,900 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-05 18:14:17,900 [DEBUG] [Provisioner] [Created workers]
# IPs : ['172.190.116.144'], ports: [50151], statuses: [1], IDs : [1]
# 2023-07-05 18:14:17,902 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-05 18:14:17,902 [DEBUG] [DividerProxy] Training Started
# 2023-07-05 18:14:17,904 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-05 18:14:17,907 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-05 18:14:17,907 [DEBUG] [Provisioner] Workers
# IPs : ['172.190.116.144'], ports: [50151], statuses: [1], IDs : [1]
# 2023-07-05 18:14:17,909 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-05 18:14:17,910 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-05 18:14:17,911 [DEBUG] [DividerAmbassador] 172.190.116.144:50151
# 2023-07-05 18:14:19,144 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-05 18:14:19,292 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-05 18:14:19,293 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-05 18:14:19,430 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 18:14:19,431 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-05 18:14:19,571 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 18:14:19,572 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-05 18:14:19,708 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-05 18:14:19,711 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-05 18:14:19,712 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-05 18:14:19,713 [DEBUG] [Divider] Divider stopped serving
# 2023-07-05 18:14:19,713 [DEBUG] [LazyProvisioner] Workers are deleted
# 2023-07-05 18:14:19,714 [INFO] [Provisioner] provisioner stopped serving

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 94.74%
