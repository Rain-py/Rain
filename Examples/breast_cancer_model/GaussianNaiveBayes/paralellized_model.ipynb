# %%
import numpy as np
import sys
# sys.path.append("../../../src/")
from Rain.Rain import Rain
# sys.path.pop()

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "local",
      "params": {}
    },
  "temp_data_path": "../../../",
  "partitions": 3,
  "num_of_workers": 3,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-05 02:36:22,937 [DEBUG] [Rain] Rain is initialized
# 2023-07-05 02:36:22,938 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-05 02:36:22,939 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-05 02:36:22,940 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-05 02:36:22,940 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-05 02:36:22,941 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-05 02:36:22,942 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-05 02:36:22,943 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-05 02:36:22,948 [DEBUG] [Rain] Creating workers
# 2023-07-05 02:36:22,954 [INFO] [Provisioner] provisioner is serving
# 2023-07-05 02:36:22,955 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-05 02:36:22,956 [INFO] [Coordinator] coordinator is serving
# 2023-07-05 02:36:22,957 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-05 02:36:22,961 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-05 02:36:22,962 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-05 02:36:22,963 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-05 02:36:22,964 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker/
# 2023-07-05 02:36:22,966 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-05 02:36:22,967 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker/
# 2023-07-05 02:36:22,969 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-05 02:36:22,970 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker/
# 2023-07-05 02:36:22,971 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-05 02:36:22,971 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-05 02:36:22,973 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-05 02:36:22,974 [DEBUG] [DividerProxy] Training Started
# 2023-07-05 02:36:22,979 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-05 02:36:22,980 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-05 02:36:22,981 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-05 02:36:22,982 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-05 02:36:22,984 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 02:36:22,984 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-05 02:36:22,985 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-05 02:36:23,011 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-05 02:36:23,011 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-05 02:36:23,014 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-05 02:36:23,016 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-05 02:36:23,016 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-05 02:36:23,018 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-05 02:36:23,019 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-05 02:36:23,021 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-05 02:36:23,023 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-05 02:36:23,023 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 02:36:23,023 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-05 02:36:23,026 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-05 02:36:23,031 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-05 02:36:23,038 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-05 02:36:23,040 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-05 02:36:23,040 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-05 02:36:23,042 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-05 02:36:23,046 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-05 02:36:23,059 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 02:36:23,059 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 02:36:23,061 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-05 02:36:23,062 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-05 02:36:23,080 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 02:36:23,090 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-05 02:36:23,094 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-05 02:36:23,098 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-05 02:36:23,108 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-05 02:36:23,117 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-05 02:36:23,121 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-05 02:36:23,123 [DEBUG] [Divider] Divider stopped serving
# 2023-07-05 02:36:23,124 [INFO] [Worker_50151] Worker stopped serving on port: 50151
# 2023-07-05 02:36:23,126 [INFO] [Worker_50152] Worker stopped serving on port: 50152
# 2023-07-05 02:36:23,127 [INFO] [Worker_50153] Worker stopped serving on port: 50153
# 2023-07-05 02:36:23,128 [DEBUG] [LocalProvisioner] Workers are deleted
# 2023-07-05 02:36:23,128 [DEBUG] [Provisioner] [Deleted workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-05 02:36:23,129 [INFO] [Provisioner] provisioner stopped serving
# sending data to dividersending data to divider
#
# sending data to divider

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 94.74%
