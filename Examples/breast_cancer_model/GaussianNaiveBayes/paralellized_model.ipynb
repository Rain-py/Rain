# %%
import numpy as np
import sys
# sys.path.append("../../../src/")
from Rain.Rain import Rain
# sys.path.pop()
# Out:
# 2023-07-05 22:37:23.778775: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-05 22:37:24.484313: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "local",
      "params": {
          "num_of_workers": 1,
        "ips": ['172.190.116.144'],
        "ports": [50151]
      }
    },
  "temp_data_path": "../../../",
  "partitions": 1,
  
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-05 22:37:25,390 [ERROR] [Rain] Error in the config: Error in partitions: argument of type 'int' is not iterable
# 2023-07-05 22:37:25,391 [DEBUG] [Rain] Rain is initialized
# 2023-07-05 22:37:25,392 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-05 22:37:25,393 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-05 22:37:25,394 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-05 22:37:25,395 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-05 22:37:25,396 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-05 22:37:25,397 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-05 22:37:25,398 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-05 22:37:25,408 [INFO] [Provisioner] provisioner is serving
# 2023-07-05 22:37:25,409 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-05 22:37:25,411 [INFO] [Coordinator] coordinator is serving
# 2023-07-05 22:37:25,413 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-05 22:37:25,417 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-05 22:37:25,419 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-05 22:37:25,420 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-05 22:37:25,421 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50151/
# 2023-07-05 22:37:25,422 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-05 22:37:25,423 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50152/
# 2023-07-05 22:37:25,425 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-05 22:37:25,426 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50153/
# 2023-07-05 22:37:25,429 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-05 22:37:25,430 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-05 22:37:25,432 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-05 22:37:25,433 [DEBUG] [DividerProxy] Training Started
# 2023-07-05 22:37:25,435 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-05 22:37:25,438 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-05 22:37:25,439 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-05 22:37:25,440 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-05 22:37:25,441 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-05 22:37:25,443 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-05 22:37:25,455 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-05 22:37:25,457 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker after sending y_train
# 2023-07-05 22:37:25,458 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-05 22:37:25,460 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-05 22:37:25,462 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-05 22:37:25,463 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-05 22:37:25,471 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker{worker_id}
# 2023-07-05 22:37:25,472 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-05 22:37:25,474 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-05 22:37:25,476 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-05 22:37:25,478 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-05 22:37:25,479 [DEBUG] [Divider] Divider stopped serving
# 2023-07-05 22:37:25,480 [INFO] [Worker_50151] Worker stopped serving on port: 50151
# 2023-07-05 22:37:25,481 [INFO] [Worker_50152] Worker stopped serving on port: 50152
# 2023-07-05 22:37:25,482 [INFO] [Worker_50153] Worker stopped serving on port: 50153
# 2023-07-05 22:37:25,482 [DEBUG] [LocalProvisioner] Workers are deleted
# 2023-07-05 22:37:25,484 [INFO] [Provisioner] provisioner stopped serving
# sending data to divider

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 94.74%
# 2023-07-05 22:38:24,355 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-05 22:39:24,143 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-05 22:45:24,528 [DEBUG] [Coordinator] coordinator is sending workers info to divider
