# %%
import numpy as np
import sys
sys.path.append("../../../src/")
from Rain.Rain import Rain
sys.path.pop()
# Out:
# '../../../src/'

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "local",
      "params": {}
    },
  "temp_data_path": "../../../../",
  "partitions": 3,
  "num_of_workers": 3,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-04 17:39:41,789 [DEBUG] [Rain] Rain is initialized
# 2023-07-04 17:39:41,789 [DEBUG] [Rain] Rain is initialized
# 2023-07-04 17:39:41,789 [DEBUG] [Rain] Rain is initialized
# 2023-07-04 17:39:41,804 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-04 17:39:41,804 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-04 17:39:41,804 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-04 17:39:41,820 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/coord/
# 2023-07-04 17:39:41,829 [DEBUG] [Coordinator Ambassador] Coordinator Ambassador is initialized
# 2023-07-04 17:39:41,829 [DEBUG] [Coordinator Ambassador] Coordinator Ambassador is initialized
# 2023-07-04 17:39:41,829 [DEBUG] [Coordinator Ambassador] Coordinator Ambassador is initialized
# 2023-07-04 17:39:41,840 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-04 17:39:41,840 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-04 17:39:41,840 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-04 17:39:41,855 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/coord/
# 2023-07-04 17:39:41,901 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-04 17:39:41,901 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-04 17:39:41,901 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-04 17:39:41,930 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/divider/
# 2023-07-04 17:39:41,944 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/divider/
# 2023-07-04 17:39:41,959 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/divider/
# 2023-07-04 17:39:41,966 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 17:39:41,966 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 17:39:41,966 [DEBUG] [DividerAmbassador] divider ambassador stopped serving

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-04 17:39:41,982 [DEBUG] [Rain] Creating workers
# 2023-07-04 17:39:41,982 [DEBUG] [Rain] Creating workers
# 2023-07-04 17:39:41,982 [DEBUG] [Rain] Creating workers
# 2023-07-04 17:39:41,991 [INFO] [Provisioner] provisioner is serving
# 2023-07-04 17:39:41,991 [INFO] [Provisioner] provisioner is serving
# 2023-07-04 17:39:41,991 [INFO] [Provisioner] provisioner is serving
# 2023-07-04 17:39:41,996 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-04 17:39:41,996 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-04 17:39:41,996 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-04 17:39:42,002 [INFO] [Coordinator] coordinator is serving
# 2023-07-04 17:39:42,002 [INFO] [Coordinator] coordinator is serving
# 2023-07-04 17:39:42,002 [INFO] [Coordinator] coordinator is serving
# 2023-07-04 17:39:42,006 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-04 17:39:42,006 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-04 17:39:42,006 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-04 17:39:42,011 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-04 17:39:42,011 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-04 17:39:42,011 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-04 17:39:42,016 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-04 17:39:42,016 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-04 17:39:42,016 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-04 17:39:42,040 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-04 17:39:42,040 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-04 17:39:42,040 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-04 17:39:42,055 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/worker/
# 2023-07-04 17:39:42,070 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-04 17:39:42,070 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-04 17:39:42,070 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-04 17:39:42,087 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/worker/
# 2023-07-04 17:39:42,102 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-04 17:39:42,102 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-04 17:39:42,102 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-04 17:39:42,120 [DEBUG] [TemporaryFilesManager] Creating temporary directory ../../../..//RainData/worker/
# 2023-07-04 17:39:42,233 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-04 17:39:42,233 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-04 17:39:42,233 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-04 17:39:42,245 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 17:39:42,245 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 17:39:42,245 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 17:39:42,260 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-04 17:39:42,260 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-04 17:39:42,260 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-04 17:39:42,272 [DEBUG] [DividerProxy] Sending data to workers
# 2023-07-04 17:39:42,272 [DEBUG] [DividerProxy] Sending data to workers
# 2023-07-04 17:39:42,272 [DEBUG] [DividerProxy] Sending data to workers
# 2023-07-04 17:39:42,290 [DEBUG] [DividerProxy] Training Started
# 2023-07-04 17:39:42,290 [DEBUG] [DividerProxy] Training Started
# 2023-07-04 17:39:42,290 [DEBUG] [DividerProxy] Training Started
# 2023-07-04 17:39:42,327 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-04 17:39:42,327 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-04 17:39:42,327 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-04 17:39:42,348 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-04 17:39:42,348 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-04 17:39:42,348 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-04 17:39:42,362 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 17:39:42,362 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 17:39:42,362 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-04 17:39:42,372 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-04 17:39:42,372 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-04 17:39:42,372 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-04 17:39:42,387 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-04 17:39:42,387 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-04 17:39:42,387 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-04 17:39:42,403 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 17:39:42,404 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 17:39:42,405 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 17:39:42,403 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 17:39:42,404 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 17:39:42,403 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-04 17:39:42,405 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 17:39:42,404 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-04 17:39:42,405 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-04 17:39:42,528 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 17:39:42,528 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 17:39:42,535 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 17:39:42,528 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 17:39:42,539 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 17:39:42,535 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 17:39:42,539 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 17:39:42,535 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 17:39:42,539 [DEBUG] [DividerAmbassador] divider is sending x train to the worker
# 2023-07-04 17:39:42,585 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 17:39:42,585 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 17:39:42,589 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 17:39:42,585 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 17:39:42,589 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 17:39:42,589 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 17:39:42,609 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/1.pkl to worker1
# 2023-07-04 17:39:42,609 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/1.pkl to worker1
# 2023-07-04 17:39:42,612 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/2.pkl to worker2
# 2023-07-04 17:39:42,609 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/1.pkl to worker1
# 2023-07-04 17:39:42,612 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/2.pkl to worker2
# 2023-07-04 17:39:42,612 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/2.pkl to worker2
# 2023-07-04 17:39:42,643 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 17:39:42,647 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 17:39:42,643 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 17:39:42,643 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-04 17:39:42,647 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 17:39:42,647 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-04 17:39:42,654 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-04 17:39:42,656 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-04 17:39:42,654 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-04 17:39:42,659 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 17:39:42,654 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-04 17:39:42,656 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-04 17:39:42,659 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 17:39:42,656 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-04 17:39:42,659 [DEBUG] [DividerAmbassador] divider is sending y train to the worker
# 2023-07-04 17:39:42,670 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-04 17:39:42,670 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-04 17:39:42,674 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/3.pkl to worker3
# 2023-07-04 17:39:42,670 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-04 17:39:42,676 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-04 17:39:42,674 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/3.pkl to worker3
# 2023-07-04 17:39:42,674 [DEBUG] [DividerAmbassador] Sending ../../../..//RainData/divider/3.pkl to worker3
# 2023-07-04 17:39:42,676 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-04 17:39:42,676 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-04 17:39:42,714 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 17:39:42,714 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 17:39:42,714 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-04 17:39:42,736 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-04 17:39:42,736 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-04 17:39:42,741 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 2
# 2023-07-04 17:39:42,736 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-04 17:39:42,745 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 1
# 2023-07-04 17:39:42,741 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 2
# 2023-07-04 17:39:42,745 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 1
# 2023-07-04 17:39:42,754 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-04 17:39:42,741 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 2
# 2023-07-04 17:39:42,745 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 1
# 2023-07-04 17:39:42,754 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-04 17:39:42,761 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-04 17:39:42,761 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-04 17:39:42,766 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-04 17:39:42,754 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-04 17:39:42,761 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-04 17:39:42,766 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-04 17:39:42,766 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-04 17:39:42,796 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-04 17:39:42,796 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-04 17:39:42,796 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-04 17:39:42,810 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-04 17:39:42,810 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-04 17:39:42,821 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 3
# 2023-07-04 17:39:42,810 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-04 17:39:42,821 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 3
# 2023-07-04 17:39:42,821 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker 3
# 2023-07-04 17:39:42,827 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-04 17:39:42,827 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-04 17:39:42,827 [DEBUG] [DividerAmbassador] divider begins downloading ../../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-04 17:39:42,856 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-04 17:39:42,856 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-04 17:39:42,856 [DEBUG] [DividerAmbassador] Downloaded ../../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-04 17:39:42,891 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# sending data to coordinator
# sending data to coordinator
# sending data to coordinator
# 2023-07-04 17:39:42,891 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-04 17:39:42,891 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-04 17:39:42,954 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 17:39:42,954 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 17:39:42,954 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 17:39:42,967 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 17:39:42,967 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 17:39:42,967 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 17:39:42,980 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 17:39:42,980 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 17:39:42,980 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-04 17:39:42,994 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 17:39:42,994 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 17:39:42,994 [DEBUG] [Divider] Divider stopped serving
# 2023-07-04 17:39:43,007 [INFO] [Provisioner] provisioner stopped serving
# 2023-07-04 17:39:43,007 [INFO] [Provisioner] provisioner stopped serving
# 2023-07-04 17:39:43,007 [INFO] [Provisioner] provisioner stopped serving

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 92.98%
