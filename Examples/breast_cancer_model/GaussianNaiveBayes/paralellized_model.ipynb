# %%
import numpy as np
import sys
sys.path.append("../../../src/")
from Rain.Rain import Rain
sys.path.pop()
# Out:
# '../../../src/'

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "local",
      "params": {
          "num_of_workers": 3,
        "ips": ['172.190.116.144'],
        "ports": [50151]
      }
    },
  "temp_data_path": "../../../",
  "partitions": 3,
  "chunk_size": 1024*1024,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-07 16:43:44,888 [DEBUG] [Rain] Rain is initialized
# 2023-07-07 16:43:44,889 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-07 16:43:44,890 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-07 16:43:44,891 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-07 16:43:44,892 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-07 16:43:44,894 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-07 16:43:44,896 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-07 16:43:44,898 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-07 16:43:44,911 [INFO] [Provisioner] provisioner is serving
# 2023-07-07 16:43:44,912 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-07 16:43:44,914 [INFO] [Coordinator] coordinator is serving
# 2023-07-07 16:43:44,915 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-07 16:43:44,921 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-07 16:43:44,923 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-07 16:43:44,924 [DEBUG] [Coordinator] coordinator is sending the number of workers to provisioner
# 2023-07-07 16:43:44,926 [DEBUG] [Provisioner] Provision requested the coordinator to get the number of workers
# 2023-07-07 16:43:44,927 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-07 16:43:44,928 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50151/
# 2023-07-07 16:43:44,931 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-07 16:43:44,932 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50152/
# 2023-07-07 16:43:44,934 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-07 16:43:44,936 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50153/
# 2023-07-07 16:43:44,939 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-07 16:43:44,940 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-07 16:43:44,942 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-07 16:43:44,944 [DEBUG] [DividerProxy] Training Started
# 2023-07-07 16:43:44,946 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-07 16:43:44,948 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-07 16:43:44,949 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-07 16:43:44,950 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-07 16:43:44,951 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-07 16:43:44,953 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-07 16:43:44,954 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-07 16:43:44,954 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-07 16:43:44,975 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-07 16:43:44,975 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-07 16:43:44,977 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-07 16:43:44,983 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 2 after sending y_train
# 2023-07-07 16:43:44,984 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 1 after sending y_train
# 2023-07-07 16:43:44,986 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-07 16:43:44,987 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 3 after sending y_train
# 2023-07-07 16:43:44,988 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-07 16:43:44,990 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-07 16:43:44,995 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-07 16:43:44,997 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-07 16:43:44,998 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-07 16:43:44,999 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-07 16:43:45,000 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-07 16:43:45,003 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-07 16:43:45,005 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-07 16:43:45,005 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-07 16:43:45,008 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-07 16:43:45,019 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-07 16:43:45,025 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-07 16:43:45,025 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-07 16:43:45,028 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-07 16:43:45,038 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-07 16:43:45,040 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-07 16:43:45,040 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-07 16:43:45,042 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-07 16:43:45,047 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-07 16:43:45,049 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-07 16:43:45,052 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-07 16:43:45,054 [DEBUG] [Divider] Divider stopped serving
# sending data to divider
# sending data to divider
# sending data to divider

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 94.74%
