# %%
import numpy as np
import sys
# sys.path.append("../../../src/")
from Rain.Rain import Rain
# sys.path.pop()

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "cloud",
      "params": {
          "num_of_workers": 1,
          "subscription_id": "a7ef3688-af58-4835-953c-e51f219fbd0f", # Mostafa's ID
          # "subscription_id":'6e14c264-a7fc-4db4-a23a-d972c21a2d99', # Menna's ID
          # "subscription_id": '82305756-d4a0-442d-8e73-625e1ced2113', # Nada's ID
          "location": 'eastus'
      }  
    },
  "temp_data_path": "../../../",
  "partitions": 3,
  "chunk_size": 1024*1024,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-07 17:44:17,692 [DEBUG] [Rain] Rain is initialized
# 2023-07-07 17:44:17,694 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-07 17:44:17,696 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData\coord/
# 2023-07-07 17:44:17,697 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-07 17:44:17,699 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-07 17:44:17,701 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData\divider/
# 2023-07-07 17:44:17,702 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData\divider/
# 2023-07-07 17:44:17,704 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData\divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-07 17:44:17,801 [INFO] [Provisioner] provisioner is serving
# 2023-07-07 17:44:17,803 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-07 17:44:17,805 [INFO] [Coordinator] coordinator is serving
# 2023-07-07 17:44:17,806 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-07 17:44:17,814 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-07 17:44:17,818 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-07 17:44:17,821 [DEBUG] [Coordinator] coordinator is sending the number of workers to provisioner
# 2023-07-07 17:44:17,824 [DEBUG] [Provisioner] Provision requested the coordinator to get the number of workers
# 2023-07-07 17:44:17,825 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-07 17:44:17,827 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData\worker_50151/
# 2023-07-07 17:44:17,833 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-07 17:44:17,835 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData\worker_50152/
# 2023-07-07 17:44:17,897 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-07 17:44:17,899 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData\worker_50153/
# 2023-07-07 17:44:17,912 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-07 17:44:17,913 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-07 17:44:17,916 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-07 17:44:17,918 [DEBUG] [DividerProxy] Training Started
# 2023-07-07 17:44:17,921 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-07 17:44:17,924 [DEBUG] [Provisioner] Received '' from the coordinator to send status
# 2023-07-07 17:44:17,932 [DEBUG] [Provisioner] Workers
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-07 17:44:17,935 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-07 17:44:17,937 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-07 17:44:17,940 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-07 17:44:17,943 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-07 17:44:17,946 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-07 17:44:17,985 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-07 17:44:17,992 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 1 after sending y_train
# 2023-07-07 17:44:17,993 [DEBUG] [DividerAmbassador] Sending ../../..//RainData\divider/1.pkl to worker1
# 2023-07-07 17:44:17,998 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-07 17:44:18,001 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-07 17:44:18,004 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-07 17:44:18,005 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-07 17:44:18,010 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-07 17:44:18,016 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 2 after sending y_train
# 2023-07-07 17:44:18,028 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 3 after sending y_train
# 2023-07-07 17:44:18,030 [DEBUG] [DividerAmbassador] Sending ../../..//RainData\divider/2.pkl to worker2
# 2023-07-07 17:44:18,031 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-07 17:44:18,032 [DEBUG] [DividerAmbassador] Sending ../../..//RainData\divider/3.pkl to worker3
# 2023-07-07 17:44:18,035 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData\divider/1_1_trained.pkl from worker1
# 2023-07-07 17:44:18,042 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-07 17:44:18,043 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-07 17:44:18,046 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-07 17:44:18,046 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-07 17:44:18,049 [INFO] [Worker_50152] Running the worker with id: 2 on iteration: 1
# 2023-07-07 17:44:18,047 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData\divider/1_1_trained.pkl from worker1 successfully
# 2023-07-07 17:44:18,054 [INFO] [Worker_50153] Running the worker with id: 3 on iteration: 1
# 2023-07-07 17:44:18,079 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-07 17:44:18,080 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-07 17:44:18,081 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData\divider/2_1_trained.pkl from worker2
# 2023-07-07 17:44:18,082 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData\divider/3_1_trained.pkl from worker3
# 2023-07-07 17:44:18,090 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData\divider/2_1_trained.pkl from worker2 successfully
# 2023-07-07 17:44:18,093 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData\divider/3_1_trained.pkl from worker3 successfully
# 2023-07-07 17:44:18,106 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-07 17:44:18,108 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-07 17:44:18,110 [DEBUG] [Divider] Divider stopped serving
# sending data to divider
# sending data to divider
# sending data to divider

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
