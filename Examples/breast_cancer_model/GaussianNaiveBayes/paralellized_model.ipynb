# %%
import numpy as np
import sys
sys.path.append("../../../src/")
from Rain.Rain import Rain
sys.path.pop()
# Out:
# '../../../src/'

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "local",
      "params": {
          "num_of_workers": 3,
        "ips": ['172.190.116.144'],
        "ports": [50151]
      }
    },
  "temp_data_path": "../../../",
  "partitions": 3,
  "chunk_size": 1024*1024,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %%
rain = Rain(config)
# Out:
# 2023-07-07 16:03:44,361 [DEBUG] [Rain] Rain is initialized
# 2023-07-07 16:03:44,367 [DEBUG] [Provisioner] Creating coordinator
# 2023-07-07 16:03:44,375 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/coord/
# 2023-07-07 16:03:44,378 [DEBUG] [Coordinator] Coordinator is initialized
# 2023-07-07 16:03:44,382 [DEBUG] [LocalProvisioner] Provisioner is initialized
# 2023-07-07 16:03:44,397 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-07 16:03:44,406 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/
# 2023-07-07 16:03:44,420 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/divider/

# %%
model = rain.train(X_train, y_train)
# Out:
# 2023-07-07 16:03:44,442 [INFO] [Provisioner] provisioner is serving
# 2023-07-07 16:03:44,443 [DEBUG] [Provisioner] Starting coordinator
# 2023-07-07 16:03:44,445 [INFO] [Coordinator] coordinator is serving
# 2023-07-07 16:03:44,448 [DEBUG] [Coordinator] sending the num of workers to the provisioner
# 2023-07-07 16:03:44,456 [DEBUG] [Provisioner] Received 'NumOfWorkers: 3
# ' from the coordinator to define the number of workers
# 2023-07-07 16:03:44,458 [DEBUG] [Coordinator] sent Success receiving the number of workers to the provisioner
# 2023-07-07 16:03:44,461 [DEBUG] [Coordinator] coordinator is sending the number of workers to provisioner
# 2023-07-07 16:03:44,462 [DEBUG] [Provisioner] Provision requested the coordinator to get the number of workers
# 2023-07-07 16:03:44,463 [DEBUG] [LocalProvisioner] Creating 3 workers
# 2023-07-07 16:03:44,470 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50151/
# 2023-07-07 16:03:44,484 [INFO] [Worker_50151] Worker is running on port: 50151
# 2023-07-07 16:03:44,494 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50152/
# 2023-07-07 16:03:44,501 [INFO] [Worker_50152] Worker is running on port: 50152
# 2023-07-07 16:03:44,511 [DEBUG] [TemporaryFilesManager] Created temporary directory ../../..//RainData/worker_50153/
# 2023-07-07 16:03:44,520 [INFO] [Worker_50153] Worker is running on port: 50153
# 2023-07-07 16:03:44,521 [DEBUG] [Provisioner] [Created workers]
# IPs : ['127.0.0.1', '127.0.0.1', '127.0.0.1'], ports: [50151, 50152, 50153], statuses: [1, 1, 1], IDs : [1, 2, 3]
# 2023-07-07 16:03:44,526 [DEBUG] [DividerAmbassador] divider ambassador is serving
# 2023-07-07 16:03:44,530 [DEBUG] [DividerProxy] Training Started
# 2023-07-07 16:03:44,532 [DEBUG] [Coordinator] coordinator is sending workers info to divider
# 2023-07-07 16:03:44,544 [DEBUG] [DividerAmbassador] divider received: information from coordinator
# 2023-07-07 16:03:44,546 [DEBUG] [MachineLearning] Starting iteration 1/1
# 2023-07-07 16:03:44,552 [DEBUG] [DividerAmbassador] 127.0.0.1:50151
# 2023-07-07 16:03:44,553 [DEBUG] [DividerAmbassador] 127.0.0.1:50152
# 2023-07-07 16:03:44,555 [DEBUG] [DividerAmbassador] 127.0.0.1:50153
# 2023-07-07 16:03:44,600 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-07 16:03:44,603 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-07 16:03:44,605 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from  worker after sending X_train
# 2023-07-07 16:03:44,647 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 3 after sending y_train
# 2023-07-07 16:03:44,648 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 2 after sending y_train
# 2023-07-07 16:03:44,650 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/3.pkl to worker3
# 2023-07-07 16:03:44,650 [DEBUG] [DividerAmbassador] divider receive: File downloaded successfully from worker 1 after sending y_train
# 2023-07-07 16:03:44,651 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/2.pkl to worker2
# 2023-07-07 16:03:44,657 [DEBUG] [DividerAmbassador] Sending ../../..//RainData/divider/1.pkl to worker1
# 2023-07-07 16:03:44,681 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 2
# 2023-07-07 16:03:44,683 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 3
# 2023-07-07 16:03:44,685 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker2
# 2023-07-07 16:03:44,686 [DEBUG] [DividerAmbassador] divider received: File downloaded successfully after sending the model to worker 1
# 2023-07-07 16:03:44,688 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker3
# 2023-07-07 16:03:44,694 [DEBUG] [DividerAmbassador] divider begins executing iteration1 for worker1
# 2023-07-07 16:03:44,700 [INFO] [Worker_50151] Running the worker with id: 1 on iteration: 1
# 2023-07-07 16:03:44,750 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker1
# 2023-07-07 16:03:44,751 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/1_1_trained.pkl from worker1
# 2023-07-07 16:03:44,759 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker2
# 2023-07-07 16:03:44,761 [DEBUG] [DividerAmbassador] divider received: Executed! after executing the model on worker3
# 2023-07-07 16:03:44,763 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/2_1_trained.pkl from worker2
# 2023-07-07 16:03:44,765 [DEBUG] [DividerAmbassador] divider begins downloading ../../..//RainData/divider/3_1_trained.pkl from worker3
# 2023-07-07 16:03:44,779 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/1_1_trained.pkl from worker1 successfully
# 2023-07-07 16:03:44,786 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/2_1_trained.pkl from worker2 successfully
# 2023-07-07 16:03:44,791 [DEBUG] [DividerAmbassador] Downloaded ../../..//RainData/divider/3_1_trained.pkl from worker3 successfully
# 2023-07-07 16:03:44,814 [DEBUG] [MachineLearning] Iteration 1/1 complete.
# 2023-07-07 16:03:44,816 [DEBUG] [DividerAmbassador] divider ambassador stopped serving
# 2023-07-07 16:03:44,819 [DEBUG] [Divider] Divider stopped serving
# sending data to divider

# %%
y_pred = model.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 92.98%
