# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB as naive_bayes_classifier_sklearn
import sys
sys.path.append('../../../src')
from Rain.Divider.MachineLearning.GaussianNaiveBayes import GaussianNaiveBayes as naive_bayes_classifier_rain
sys.path.pop()
# Out:
# '../../../src'

# %%
import os

def clean():
    folder_paths = ["logs"]  # Replace with the folder path you want to delete files from
    file_extensions = [".npy", ".pkl", ".log"]  # Replace with the file extension you want to delete
    for folder_path in folder_paths:
        if os.path.exists(folder_path):
            for filename in os.listdir(folder_path):
                for file_extension in file_extensions:
                    if filename.endswith(file_extension):
                        file_path = os.path.join(folder_path, filename)
                        os.remove(file_path)
clean()

# %%
def get_train_data():
    return np.load("../../../data/breast_cancer/train_data.npy"), np.load("../../../data/breast_cancer/train_labels.npy")

def get_test_data():
    return np.load("../../../data/breast_cancer/test_data.npy"), np.load("../../../data/breast_cancer/test_labels.npy")

# %%
X_train, y_train = get_train_data()
X_test, y_test = get_test_data()

# %%
config = {
  "mode": {
      "type": "local",
      "params": {}
    },
  "temp_data_path": "../../../../",
  "partitions": 3,
  "num_of_workers": 3,
  "learning_type": "ML",
  "ML": {
      "algorithm": {
      "type": "GaussianNaiveBayes",
    }    
  }
}

# %% [markdown]
# ### Sklearn - NaiveBayes

# %%
# create naive bayes classifier
naive_bayes_classifier = naive_bayes_classifier_sklearn(var_smoothing=0)
naive_bayes_classifier.fit(X_train, y_train)
y_pred_sklearn = naive_bayes_classifier.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred_sklearn == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 92.98%

# %% [markdown]
# ### Rain - NaiveBayes

# %%
# create naive bayes classifier
naive_bayes_classifier = naive_bayes_classifier_rain()
naive_bayes_classifier.fit(X_train, y_train)
y_pred_rain = naive_bayes_classifier.predict(X_test)
print(f"Accuracy of naive bayes classifier is: {(np.sum(y_pred_rain == y_test) / len(y_test) * 100).round(2)}%")
# Out:
# Accuracy of naive bayes classifier is: 92.98%

# %%
print((y_pred_rain == y_pred_sklearn).sum() / len(y_pred_sklearn))
assert ((y_pred_rain == y_pred_sklearn).sum()) == len(y_pred_sklearn), "Gaussian Naive Bayes classifier is not implemented correctly!"
# Out:
# 1.0
